# %%
# !pip install -q transformers

# %%
# !pip install biopython
# Out:
# Requirement already satisfied: biopython in /usr/local/lib/python3.10/dist-packages (1.83)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython) (1.25.2)

# %%
#!pip3 uninstall --yes torch torchaudio torchvision torchtext torchdata
# !pip3 install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.40)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
import os
import math
import numpy as np
import random
import logging

# Bring in PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
# Most of the examples have typing on the signatures for readability
from typing import Optional, Callable, List, Tuple
from Bio import SeqIO
# For data loading
from torch.utils.data import Dataset, IterableDataset, TensorDataset, DataLoader
import json
import glob
import gzip
import bz2

# For progress and timing
from tqdm import tqdm
import time
import shutil
from Bio.PDB import PDBList
from Bio.PDB.MMCIFParser import MMCIFParser
import re

#phi and psi
from Bio.PDB import PICIO, PDBIO
from Bio import PDB
from typing import TypedDict, Dict, Tuple

from Bio import Entrez
from Bio.PDB import PDBList
import pandas as pd

from transformers import BertModel, BertTokenizer
import re

from torch.utils.data import Dataset, DataLoader
from torch.utils.data import TensorDataset, DataLoader, random_split

# %% [markdown]
# Retrieving data from pdb bank using pisces ids with filter

# %%
def download_pdb_files(pdb_ids, output_dir):
  pdbl = PDBList()
  for pdb_id in pdb_ids:
    pdb_id_trimmed = pdb_id[:-1] #for some reason the last letter is random, we have to remove it to retrieve the ids
    pdbl.retrieve_pdb_file(pdb_id_trimmed, pdir=output_dir, file_format='pdb') #maybe change it to mm.cif?

file_path = '/content/cullpdb_pc30.0_res0.0-2.0_noBrks_noDsdr_len40-10000_R0.25_Nmr_d2024_06_13_chains2636'
df = pd.read_csv(file_path, delim_whitespace=True)

#pdb_ids = df['PDBchain'].tolist()

df = df[df['len'] <= 128]
pdb_ids = df['PDBchain'].tolist()
print(pdb_ids)

download_pdb_files(pdb_ids, '/content/target directory')
# Out:
# ['1E0ZA', '1RY4A', '1UG7A', '1WHNA', '2AYAA', '2D87A', '2DB5A', '2DKPA', '2EBKA', '2ETTA', '2FM4A', '2I4KA', '2JQ5A', '2K0RA', '2K5TA', '2LR4A', '2LS01', '2LVLA', '2MAHA', '2NCNA', '2RLOA', '2RV8A', '2YTUA', '4AR0A', '5AIWA', '5H7UA', '5N9QA', '8E22X', '1CMOA', '1DDFA', '1EALA', '1PQNA', '1QKLA', '1UEYA', '1W2QA', '1WH4A', '1WJRA', '1X5MA', '1ZU1A', '2CSOA', '2DMKA', '2EE7A', '2L1LB', '2LOEA', '2MF7A', '2MPLA', '2NBOA', '2TMPA', '4UEIA', '5M1UA', '7XRWA', '8OILA', '1RSFA', '1V5SA', '1X5EA', '1ZO0A', '2A4HA', '2CR4A', '2DAVA', '2IF1A', '2JP2A', '2JVNA', '2K2VA', '2L3GA', '2L57A', '2LBCA', '2LLNA', '2M26A', '3MSPA', '7F7NA', '7KNVA', '8SQXA', '1BUQA', '1BW3A', '1FR0A', '1GIOA', '1MH6A', '1PSYA', '1UENA', '1WYJA', '2AI6A', '2DHJA', '2K4VA', '2K4ZA', '2KA5A', '2KFPA', '2KYTA', '2L2CA', '2LDUA', '2LM0A', '2MDKA', '2MV4A', '2N2HB', '2NBGA', '2PRFA', '4A53A', '5KNWA', '5T3YA', '5WOEA', '6GWMA', '6TH8A', '6UF2A', '6XEHA', '7BQCA', '7PRDA', '7QYIA', '1DC7A', '1E8EA', '1EO1A', '1PIRA', '1T3VA', '1WELA', '1WGVA', '1WHRA', '1WISA', '1WJ4A', '1WJOA', '1X52A', '2COMA', '2CPRA', '2D5UA', '2E5IA', '2JWNA', '2KA0A', '2KIEA', '2KV1A', '2LLIA', '2M4MA', '5UKEA', '5WQZA', '6S3WA', '6X1KA', '7BPNA', '1QCEA', '1RZWA', '1T2RA', '1TUJA', '1V60A', '1WGOA', '2DATA', '2EDDA', '2GA5A', '2GW6A', '2K2OA', '2K54A', '2KSCA', '2LBOA', '2LPMA', '2LVMA', '2M0QA', '2N3OA', '2P80D', '2YQGA', '6NBNA', '8I25A', '1AXJA', '1BIPA', '1D4BA', '1DROA', '1IT4A', '1NR3A', '1PLOA', '1V5QA', '1YUAA', '2CQMA', '2CRYA', '2EQYA', '2KUTA', '2LFIA', '2LHTA', '2M5YA', '2MWIA', '2MZNA', '2ROHA', '2YS4A', '5Y7LA', '6QS0A', '7BQSA', '7S0NA', '1QW1A', '1YZSA', '1Z2FA', '2D88A', '2DLLA', '2EDOA', '2HRJA', '2KDCA', '2KKVA', '2KRTA', '2LBWA', '2LXFA', '2LY8A', '2MMZA', '2RQ5A', '6BYVA', '6F8EA', '7NY0A', '1BR0A', '1MW4A', '1RQUA', '1RYUA', '1WFUA', '1WJ5A', '1X5FA', '2BO5A', '2CRVA', '2D9XA', '2DHZA', '2DMEA', '2KCDA', '2KOKA', '2KVOA', '2KYMA', '2L1NA', '2L4WA', '2MBLA', '2MHCA', '2YUXA', '5KPEA', '6RPVA', '8FA3A', '1BAKA', '1FHOA', '1JFNA', '1N3JA', '1UJXA', '1W9RA', '1WI5A', '1X0OA', '1X6DA', '1YR1A', '2DB2A', '2J48A', '2KDXA', '2KQ1A', '2LJPA', '2LKPA', '2LTLA', '2LWFA', '2M3KA', '2MDTA', '2MEMA', '2MQDA', '2N4IA', '2RQRA', '2YQRA', '2YSTA', '2YSXA', '5IRDA', '6DL4A', '6O1QA', '6QVWA', '6SAPA', '8BA1A', '1HCDA', '1L2MA', '1RJHA', '1TUZA', '1V6BA', '2DAFA', '2DLZA', '2E7CA', '2JZ3B', '2K49A', '2KD1A', '2KHCA', '2KJ8A', '2KL4A', '2LSHA', '2M2DA', '2MKCA', '2MW1A', '2NBBA', '2NCGA', '2PXGA', '2W0NA', '2YUBA', '5LSDA', '6DSLB', '6IVUB', '6YE5A', '1C9QA', '1D6TA', '1K0HA', '1KMDA', '1QTTA', '1UW0A', '2CPTA', '2HC5A', '2HGKA', '2JSFA', '2KKPA', '2KTSA', '2LJKA', '2MNAA', '2ROVA', '5JYUA', '5LFIA', '6MI5X', '8GDGA', '1AUZA', '1FHTA', '1SR2A', '1TOZA', '1UF0A', '1WGHA', '1WXAA', '2BYFA', '2C34A', '2DL1A', '2GDTA', '2K32A', '2K87A', '2KJ5A', '2KKQA', '2KT9A', '2LI6A', '2LUIA', '4BEHB', '5KESA', '5O2YA', '6XTTB', '6Z29A', '8BA1B', '1I4VA', '1KLPA', '1WE7A', '1Y5OA', '1ZDVA', '2CODA', '2CUHA', '2DMIA', '2HW0A', '2JW1A', '2KATA', '2KMFA', '2LFDA', '2MPWA', '2RSMA', '6FEGA', '6G7GA', '6GT7A', '6YELA', '8TZMA', '1AKPA', '1ENWA', '1EWIA', '1JWEA', '1LL8A', '1V87A', '1V9VA', '1WGKA', '1X4YA', '1YNXA', '2APNA', '2CQ4A', '2EJEA', '2KLQA', '2KPPA', '2L0DA', '2L6OA', '2LVFA', '2M0AA', '2MC8A', '2MSXA', '2RNNA', '2YRPA', '5KIZA', '5MRGA', '6FZKA', '6JPPA', '7CSQB', '7L6KA', '7OZ0A', '8CA0A', '8Y4ZA', '1GA3A', '1N3GA', '1PLSA', '1WI0A', '1XNEA', '1Y7XA', '2COKA', '2DGZA', '2E2WA', '2EDHA', '2IVWA', '2LCHA', '2LFGA', '2M1CA', '2MUKX', '2RPBA', '4CSQA', '5NR5A', '6I2OA', '6ZYGA', '1IRSA', '1J26A', '1JLIA', '1K19A', '1KLAA', '1Q53A', '1QN0A', '1SJGA', '1WJWA', '1X0HA', '2COCA', '2CRQA', '2CUIA', '2E6JA', '2E6QA', '2E7OA', '2EBUA', '2JRKA', '2KCKA', '2KEYA', '2KZ4A', '2LKYA', '2LZJA', '2MX7A', '5KGQA', '7R3MA', '1BC4A', '1D4UA', '1EIWA', '1FYBA', '1JI8A', '1MP1A', '1TDPA', '1WHXA', '1WWQA', '1X5LA', '2CPIA', '2DCEA', '2DGYA', '2HJQA', '2JZVA', '2K2BA', '2K4NA', '2KDEA', '2KIWA', '2L3LA', '2N9GA', '2NBMA', '2V ...
# Downloading PDB structure '1e0z'...
# Downloading PDB structure '1ry4'...
# Downloading PDB structure '1ug7'...
# Downloading PDB structure '1whn'...
# Downloading PDB structure '2aya'...
# Downloading PDB structure '2d87'...
# Downloading PDB structure '2db5'...
# Downloading PDB structure '2dkp'...
# Downloading PDB structure '2ebk'...
# Downloading PDB structure '2ett'...
# Downloading PDB structure '2fm4'...
# Downloading PDB structure '2i4k'...
# Downloading PDB structure '2jq5'...
# Downloading PDB structure '2k0r'...
# Downloading PDB structure '2k5t'...
# Downloading PDB structure '2lr4'...
# Downloading PDB structure '2ls0'...
# Downloading PDB structure '2lvl'...
# Downloading PDB structure '2mah'...
# Downloading PDB structure '2ncn'...
# Downloading PDB structure '2rlo'...
# Downloading PDB structure '2rv8'...
# Downloading PDB structure '2ytu'...
# Downloading PDB structure '4ar0'...
# Downloading PDB structure '5aiw'...
# Downloading PDB structure '5h7u'...
# Downloading PDB structure '5n9q'...
# Downloading PDB structure '8e22'...
# Downloading PDB structure '1cmo'...
# Downloading PDB structure '1ddf'...
# Downloading PDB structure '1eal'...
# Downloading PDB structure '1pqn'...
# Downloading PDB structure '1qkl'...
# Downloading PDB structure '1uey'...
# Downloading PDB structure '1w2q'...
# Downloading PDB structure '1wh4'...
# Downloading PDB structure '1wjr'...
# Downloading PDB structure '1x5m'...
# Downloading PDB structure '1zu1'...
# Downloading PDB structure '2cso'...
# Downloading PDB structure '2dmk'...
# Downloading PDB structure '2ee7'...
# Downloading PDB structure '2l1l'...
# Downloading PDB structure '2loe'...
# Downloading PDB structure '2mf7'...
# Downloading PDB structure '2mpl'...
# Downloading PDB structure '2nbo'...
# Downloading PDB structure '2tmp'...
# Downloading PDB structure '4uei'...
# Downloading PDB structure '5m1u'...
# Downloading PDB structure '7xrw'...
# Downloading PDB structure '8oil'...
# Downloading PDB structure '1rsf'...
# Downloading PDB structure '1v5s'...
# Downloading PDB structure '1x5e'...
# Downloading PDB structure '1zo0'...
# Downloading PDB structure '2a4h'...
# Downloading PDB structure '2cr4'...
# Downloading PDB structure '2dav'...
# Downloading PDB structure '2if1'...
# Downloading PDB structure '2jp2'...
# Downloading PDB structure '2jvn'...
# Downloading PDB structure '2k2v'...
# Downloading PDB structure '2l3g'...
# Downloading PDB structure '2l57'...
# Downloading PDB structure '2lbc'...
# Downloading PDB structure '2lln'...
# Downloading PDB structure '2m26'...
# Downloading PDB structure '3msp'...
# Downloading PDB structure '7f7n'...
# Downloading PDB structure '7knv'...
# Downloading PDB structure '8sqx'...
# Downloading PDB structure '1buq'...
# Downloading PDB structure '1bw3'...
# Downloading PDB structure '1fr0'...
# Downloading PDB structure '1gio'...
# Downloading PDB structure '1mh6'...
# Downloading PDB structure '1psy'...
# Downloading PDB structure '1uen'...
# Downloading PDB structure '1wyj'...
# Downloading PDB structure '2ai6'...
# Downloading PDB structure '2dhj'...
# Downloading PDB structure '2k4v'...
# Downloading PDB structure '2k4z'...
# Downloading PDB structure '2ka5'...
# Downloading PDB structure '2kfp'...
# Downloading PDB structure '2kyt'...
# Downloading PDB structure '2l2c'...
# Downloading PDB structure '2ldu'...
# Downloading PDB structure '2lm0'...
# Downloading PDB structure '2mdk'...
# Downloading PDB structure '2mv4'...
# Downloading PDB structure '2n2h'...
# Downloading PDB structure '2nbg'...
# Downloading PDB structure '2prf'...
# Downloading PDB structure '4a53'...
# Downloading PDB structure '5knw'...
# Downloading PDB structure '5t3y'...
# Downloading PDB structure '5woe'...
# Downloading PDB structure '6gwm'...
# Downloading PDB structure '6th8'...
# Downloading PDB structure '6uf2'...
# Downloading PDB structure '6xeh'...
# Downloading PDB structure '7bqc'...
# Downloading PDB structure '7prd'...
# Downloading PDB structure '7qyi'...
# Downloading PDB structure '1dc7'...
# Downloading PDB structure '1e8e'...
# Downloading PDB structure '1eo1'...
# Downloading PDB structure '1pir'...
# Downloading PDB structure '1t3v'...
# Downloading PDB structure '1wel'...
# Downloading PDB structure '1wgv'...
# Downloading PDB structure '1whr'...
# Downloading PDB structure '1wis'...
# Downloading PDB structure '1wj4'...
# Downloading PDB structure '1wjo'...
# Downloading PDB structure '1x52'...
# Downloading PDB structure '2com'...
# Downloading PDB structure '2cpr'...
# Downloading PDB structure '2d5u'...
# Downloading PDB structure '2e5i'...
# Downloading PDB structure '2jwn'...
# Downloading PDB structure '2ka0'...
# Downloading PDB structure '2kie'...
# Downloading PDB structure '2kv1'...
# Downloading PDB structure '2lli'...
# Downloading PDB structure '2m4m'...
# Downloading PDB structure '5uke'...
# Downloading PDB structure '5wqz'...
# Downloading PDB structure '6s3w'...
# Downloading PDB structure '6x1k'...
# Downloading PDB structure '7bpn'...
# Downloading PDB structure '1qce'...
# Downloading PDB structure '1rzw'...
# Downloading PDB structure '1t2r'...
# Downloading PDB structure '1tuj'...
# Downloading PDB structure '1v60'...
# Downloading PDB structure '1wgo'...
# Downloading PDB structure '2dat'...
# Downloading PDB structure '2edd'...
# Downloading PDB structure '2ga5'...
# Downloading PDB structure '2gw6'...
# Downloading PDB structure '2k2o'...
# Downloading PDB structure '2k54'...
# Downloading PDB structure '2ksc'...
# Downloading PDB structure '2lbo'...
# Downloading PDB structure '2lpm'...
# Downloading PDB structure '2lvm'...
# Downloading PDB structure '2m0q'...
# Downloading PDB structure '2n3o'...
# Downloading PDB structure '2p80'...
# Downloading PDB structure '2yqg'...
# Downloading PDB structure '6nbn'...
# Downloading PDB structure '8i25'...
# Downloading PDB structure '1axj'...
# Downloading PDB structure '1bip'...
# Downloading PDB structure '1d4b'...
# Downloading PDB structure '1dro'...
# Downloading PDB structure '1it4'...
# Downloading PDB structure '1nr3'...
# Downloading PDB structure '1plo'...
# Downloading PDB structure '1v5q'...
# Downloading PDB structure '1yua'...
# Downloading PDB structure '2cqm'...
# Downloading PDB structure '2cry'...
# Downloading PDB structure '2eqy'...
# Downloading PDB structure '2kut'...
# Downloading PDB structure '2lfi'...
# Downloading PDB structure '2lht'...
# Downloading PDB structure '2m5y'...
# Downloading PDB structure '2mwi'...
# Downloading PDB structure '2mzn'...
# Downloading PDB structure '2roh'...
# Downloading PDB structure '2ys4'...
# Downloading PDB structure '5y7l'...
# Downloading PDB structure '6qs0'...
# Downloading PDB structure '7bqs'...
# Downloading PDB structure '7s0n'...
# Downloading PDB structure '1qw1'...
# Downloading PDB structure '1yzs'...
# Downloading PDB structure '1z2f'...
# Downloading PDB structure '2d88'...
# Downloading PDB structure '2dll'...
# Downloading PDB structure '2edo'...
# Downloading PDB structure '2hrj'...
# Downloading PDB structure '2kdc'...
# Downloading PDB structure '2kkv'...
# Downloading PDB structure '2krt'...
# Downloading PDB structure '2lbw'...
# Downloading PDB structure '2lxf'...
# Downloading PDB structure '2ly8'...
# Downloading PDB structure '2mmz'...
# Downloading PDB structure '2rq5'...
# Downloading PDB structure '6byv'...
# Downloading PDB structure '6f8e'...
# Downloading PDB structure '7ny0'...
# Downloading PDB structure '1br0'...
# Downloading PDB structure '1mw4'...
# Downloading PDB structure '1rqu'...
# Downloading PDB structure '1ryu'...
# Downloading PDB structure '1wfu'...
# Downloading PDB structure '1wj5'...
# Downloading PDB structure '1x5f'...
# Downloading PDB structure '2bo5'...
# Downloading PDB structure '2crv'...
# Downloading PDB structure '2d9x'...
# Downloading PDB structure '2dhz'...
# Downloading PDB structure '2dme'...
# Downloading PDB structure '2kcd'...
# Downloading PDB structure '2kok'...
# Downloading PDB structure '2kvo'...
# Downloading PDB structure '2kym'...
# Downloading PDB structure '2l1n'...
# Downloading PDB structure '2l4w'...
# Downloading PDB structure '2mbl'...
# Downloading PDB structure '2mhc'...
# Downloading PDB structure '2yux'...
# Downloading PDB structure '5kpe'...
# Downloading PDB structure '6rpv'...
# Downloading PDB structure '8fa3'...
# Downloading PDB structure '1bak'...
# Downloading PDB structure '1fho'...
# Downloading PDB structure '1jfn'...
# Downloading PDB structure '1n3j'...
# Downloading PDB structure '1ujx'...
# Downloading PDB structure '1w9r'...
# Downloading PDB structure '1wi5'...
# Downloading PDB structure '1x0o'...
# Downloading PDB structure '1x6d'...
# Downloading PDB structure '1yr1'...
# Downloading PDB structure '2db2'...
# Downloading PDB structure '2j48'...
# Downloading PDB structure '2kdx'...
# Downloading PDB structure '2kq1'...
# Downloading PDB structure '2ljp'...
# Downloading PDB structure '2lkp'...
# Downloading PDB structure '2ltl'...
# Downloading PDB structure '2lwf'...
# Downloading PDB structure '2m3k'...
# Downloading PDB structure '2mdt'...
# Downloading PDB structure '2mem'...
# Downloading PDB structure '2mqd'...
# Downloading PDB structure '2n4i'...
# Downloading PDB structure '2rqr'...
# Downloading PDB structure '2yqr'...
# Downloading PDB structure '2yst'...
# Downloading PDB structure '2ysx'...
# Downloading PDB structure '5ird'...
# Downloading PDB structure '6dl4'...
# Downloading PDB structure '6o1q'...
# Downloading PDB structure '6qvw'...
# Downloading PDB structure '6sap'...
# Downloading PDB structure '8ba1'...
# Downloading PDB structure '1hcd'...
# Downloading PDB structure '1l2m'...
# Downloading PDB structure '1rjh'...
# Downloading PDB structure '1tuz'...
# Downloading PDB structure '1v6b'...
# Downloading PDB structure '2daf'...
# Downloading PDB structure '2dlz'...
# Downloading PDB structure '2e7c'...
# Downloading PDB structure '2jz3'...
# Downloading PDB structure '2k49'...
# Downloading PDB structure '2kd1'...
# Downloading PDB structure '2khc'...
# Downloading PDB structure '2kj8'...
# Downloading PDB structure '2kl4'...
# Downloading PDB structure '2lsh'...
# Downloading PDB structure '2m2d'...
# Downloading PDB structure '2mkc'...
# Downloading PDB structure '2mw1'...
# Downloading PDB structure '2nbb'...
# Downloading PDB structure '2ncg'...
# Downloading PDB structure '2pxg'...
# Downloading PDB structure '2w0n'...
# Downloading PDB structure '2yub'...
# Downloading PDB structure '5lsd'...
# Downloading PDB structure '6dsl'...
# Downloading PDB structure '6ivu'...
# Downloading PDB structure '6ye5'...
# Downloading PDB structure '1c9q'...
# Downloading PDB structure '1d6t'...
# Downloading PDB structure '1k0h'...
# Downloading PDB structure '1kmd'...
# Downloading PDB structure '1qtt'...
# Downloading PDB structure '1uw0'...
# Downloading PDB structure '2cpt'...
# Downloading PDB structure '2hc5'...
# Downloading PDB structure '2hgk'...
# Downloading PDB structure '2jsf'...
# Downloading PDB structure '2kkp'...
# Downloading PDB structure '2kts'...
# Downloading PDB structure '2ljk'...
# Downloading PDB structure '2mna'...
# Downloading PDB structure '2rov'...
# Downloading PDB structure '5jyu'...
# Downloading PDB structure '5lfi'...
# Downloading PDB structure '6mi5'...
# Downloading PDB structure '8gdg'...
# Downloading PDB structure '1auz'...
# Downloading PDB structure '1fht'...
# Downloading PDB structure '1sr2'...
# Downloading PDB structure '1toz'...
# Downloading PDB structure '1uf0'...
# Downloading PDB structure '1wgh'...
# Downloading PDB structure '1wxa'...
# Downloading PDB structure '2byf'...
# Downloading PDB structure '2c34'...
# Downloading PDB structure '2dl1'...
# Downloading PDB structure '2gdt'...
# Downloading PDB structure '2k32'...
# Downloading PDB structure '2k87'...
# Downloading PDB structure '2kj5'...
# Downloading PDB structure '2kkq'...
# Downloading PDB structure '2kt9'...
# Downloading PDB structure '2li6'...
# Downloading PDB structure '2lui'...
# Downloading PDB structure '4beh'...
# Downloading PDB structure '5kes'...
# Downloading PDB structure '5o2y'...
# Downloading PDB structure '6xtt'...
# Downloading PDB structure '6z29'...
# Structure exists: '/content/target directory/pdb8ba1.ent'
# Downloading PDB structure '1i4v'...
# Downloading PDB structure '1klp'...
# Downloading PDB structure '1we7'...
# Downloading PDB structure '1y5o'...
# Downloading PDB structure '1zdv'...
# Downloading PDB structure '2cod'...
# Downloading PDB structure '2cuh'...
# Downloading PDB structure '2dmi'...
# Downloading PDB structure '2hw0'...
# Downloading PDB structure '2jw1'...
# Downloading PDB structure '2kat'...
# Downloading PDB structure '2kmf'...
# Downloading PDB structure '2lfd'...
# Downloading PDB structure '2mpw'...
# Downloading PDB structure '2rsm'...
# Downloading PDB structure '6feg'...
# Downloading PDB structure '6g7g'...
# Downloading PDB structure '6gt7'...
# Downloading PDB structure '6yel'...
# Downloading PDB structure '8tzm'...
# Downloading PDB structure '1akp'...
# Downloading PDB structure '1enw'...
# Downloading PDB structure '1ewi'...
# Downloading PDB structure '1jwe'...
# Downloading PDB structure '1ll8'...
# Downloading PDB structure '1v87'...
# Downloading PDB structure '1v9v'...
# Downloading PDB structure '1wgk'...
# Downloading PDB structure '1x4y'...
# Downloading PDB structure '1ynx'...
# Downloading PDB structure '2apn'...
# Downloading PDB structure '2cq4'...
# Downloading PDB structure '2eje'...
# Downloading PDB structure '2klq'...
# Downloading PDB structure '2kpp'...
# Downloading PDB structure '2l0d'...
# Downloading PDB structure '2l6o'...
# Downloading PDB structure '2lvf'...
# Downloading PDB structure '2m0a'...
# Downloading PDB structure '2mc8'...
# Downloading PDB structure '2msx'...
# Downloading PDB structure '2rnn'...
# Downloading PDB structure '2yrp'...
# Downloading PDB structure '5kiz'...
# Downloading PDB structure '5mrg'...
# Downloading PDB structure '6fzk'...
# Downloading PDB structure '6jpp'...
# Downloading PDB structure '7csq'...
# Downloading PDB structure '7l6k'...
# Downloading PDB structure '7oz0'...
# Downloading PDB structure '8ca0'...
# Downloading PDB structure '8y4z'...
# Downloading PDB structure '1ga3'...
# Downloading PDB structure '1n3g'...
# Downloading PDB structure '1pls'...
# Downloading PDB structure '1wi0'...
# Downloading PDB structure '1xne'...
# Downloading PDB structure '1y7x'...
# Downloading PDB structure '2cok'...
# Downloading PDB structure '2dgz'...
# Downloading PDB structure '2e2w'...
# Downloading PDB structure '2edh'...
# Downloading PDB structure '2ivw'...
# Downloading PDB structure '2lch'...
# Downloading PDB structure '2lfg'...
# Downloading PDB structure '2m1c'...
# Downloading PDB structure '2muk'...
# Downloading PDB structure '2rpb'...
# Downloading PDB structure '4csq'...
# Downloading PDB structure '5nr5'...
# Downloading PDB structure '6i2o'...
# Downloading PDB structure '6zyg'...
# Downloading PDB structure '1irs'...
# Downloading PDB structure '1j26'...
# Downloading PDB structure '1jli'...
# Downloading PDB structure '1k19'...
# Downloading PDB structure '1kla'...
# Downloading PDB structure '1q53'...
# Downloading PDB structure '1qn0'...
# Downloading PDB structure '1sjg'...
# Downloading PDB structure '1wjw'...
# Downloading PDB structure '1x0h'...
# Downloading PDB structure '2coc'...
# Downloading PDB structure '2crq'...
# Downloading PDB structure '2cui'...
# Downloading PDB structure '2e6j'...
# Downloading PDB structure '2e6q'...
# Downloading PDB structure '2e7o'...
# Downloading PDB structure '2ebu'...
# Downloading PDB structure '2jrk'...
# Downloading PDB structure '2kck'...
# Downloading PDB structure '2key'...
# Downloading PDB structure '2kz4'...
# Downloading PDB structure '2lky'...
# Downloading PDB structure '2lzj'...
# Downloading PDB structure '2mx7'...
# Downloading PDB structure '5kgq'...
# Downloading PDB structure '7r3m'...
# Downloading PDB structure '1bc4'...
# Downloading PDB structure '1d4u'...
# Downloading PDB structure '1eiw'...
# Downloading PDB structure '1fyb'...
# Downloading PDB structure '1ji8'...
# Downloading PDB structure '1mp1'...
# Downloading PDB structure '1tdp'...
# Downloading PDB structure '1whx'...
# Downloading PDB structure '1wwq'...
# Downloading PDB structure '1x5l'...
# Downloading PDB structure '2cpi'...
# Downloading PDB structure '2dce'...
# Downloading PDB structure '2dgy'...
# Downloading PDB structure '2hjq'...
# Downloading PDB structure '2jzv'...
# Downloading PDB structure '2k2b'...
# Downloading PDB structure '2k4n'...
# Downloading PDB structure '2kde'...
# Downloading PDB structure '2kiw'...
# Downloading PDB structure '2l3l'...
# Downloading PDB structure '2n9g'...
# Downloading PDB structure '2nbm'...
# Downloading PDB structure '2v1n'...
# Downloading PDB structure '2yqf'...
# Downloading PDB structure '5b7j'...
# Downloading PDB structure '5u3h'...
# Downloading PDB structure '5vzm'...
# Downloading PDB structure '7pmp'...
# Downloading PDB structure '7vh9'...
# Downloading PDB structure '1a5j'...
# Downloading PDB structure '1bnr'...
# Downloading PDB structure '1exg'...
# Downloading PDB structure '1hn6'...
# Downloading PDB structure '1oqa'...
# Downloading PDB structure '1rjv'...
# Downloading PDB structure '1tkn'...
# Downloading PDB structure '1ujr'...
# Downloading PDB structure '1wxp'...
# Downloading PDB structure '1ygo'...
# Downloading PDB structure '2bye'...
# Downloading PDB structure '2c06'...
# Downloading PDB structure '2cq8'...
# Downloading PDB structure '2daq'...
# Downloading PDB structure '2db8'...
# Downloading PDB structure '2diq'...
# Downloading PDB structure '2dm2'...
# Downloading PDB structure '2h7a'...
# Downloading PDB structure '2k24'...
# Downloading PDB structure '2khq'...
# Downloading PDB structure '2kl5'...
# Downloading PDB structure '2kpo'...
# Downloading PDB structure '2ksh'...
# Downloading PDB structure '2mek'...
# Downloading PDB structure '2mhd'...
# Downloading PDB structure '2n6e'...
# Downloading PDB structure '2nas'...
# Downloading PDB structure '2yuw'...
# Downloading PDB structure '6qbz'...
# Downloading PDB structure '1bj8'...
# Downloading PDB structure '1cto'...
# Downloading PDB structure '1oh1'...
# Downloading PDB structure '1sm7'...
# Downloading PDB structure '1t0g'...
# Downloading PDB structure '1uc6'...
# Downloading PDB structure '1vd0'...
# Downloading PDB structure '1x4a'...
# Downloading PDB structure '2cop'...
# Downloading PDB structure '2cou'...
# Downloading PDB structure '2cr5'...
# Downloading PDB structure '2d96'...
# Downloading PDB structure '2fqh'...
# Downloading PDB structure '2k0a'...
# Downloading PDB structure '2k3i'...
# Downloading PDB structure '2k7m'...
# Downloading PDB structure '2kbn'...
# Downloading PDB structure '2kca'...
# Downloading PDB structure '2l1t'...
# Downloading PDB structure '2l2q'...
# Downloading PDB structure '2l9q'...
# Downloading PDB structure '2lm4'...
# Downloading PDB structure '2lxe'...
# Downloading PDB structure '2m8r'...
# Downloading PDB structure '2mab'...
# Downloading PDB structure '2n32'...
# Downloading PDB structure '2rq1'...
# Downloading PDB structure '2z59'...
# Downloading PDB structure '5y0u'...
# Downloading PDB structure '6tob'...
# Downloading PDB structure '6z35'...
# Downloading PDB structure '8c7k'...
# Downloading PDB structure '8dpx'...
# Downloading PDB structure '1ac0'...
# Downloading PDB structure '1c3y'...
# Downloading PDB structure '1fhb'...
# Downloading PDB structure '1n91'...
# Downloading PDB structure '1xsf'...
# Downloading PDB structure '2cqy'...
# Downloading PDB structure '2cs8'...
# Downloading PDB structure '2cuj'...
# Downloading PDB structure '2dne'...
# Downloading PDB structure '2h2m'...
# Downloading PDB structure '2i96'...
# Downloading PDB structure '2jnz'...
# Downloading PDB structure '2jqo'...
# Downloading PDB structure '2kcj'...
# Downloading PDB structure '2kob'...
# Downloading PDB structure '2kpy'...
# Downloading PDB structure '2l89'...
# Downloading PDB structure '2l9d'...
# Downloading PDB structure '2lc2'...
# Downloading PDB structure '2lor'...
# Downloading PDB structure '2lv5'...
# Downloading PDB structure '2lxu'...
# Downloading PDB structure '2moi'...
# Downloading PDB structure '2n39'...
# Downloading PDB structure '2rn7'...
# Downloading PDB structure '5frf'...
# Downloading PDB structure '5tm0'...
# Downloading PDB structure '6cws'...
# Downloading PDB structure '7tod'...
# Downloading PDB structure '1i17'...
# Downloading PDB structure '1ie5'...
# Downloading PDB structure '1nso'...
# Downloading PDB structure '1q6a'...
# Downloading PDB structure '1rmj'...
# Downloading PDB structure '1wjq'...
# Downloading PDB structure '2cof'...
# Downloading PDB structure '2dbd'...
# Downloading PDB structure '2e0g'...
# Downloading PDB structure '2gd7'...
# Downloading PDB structure '2jvl'...
# Downloading PDB structure '2ksf'...
# Downloading PDB structure '2lhk'...
# Downloading PDB structure '2llf'...
# Downloading PDB structure '2ltm'...
# Downloading PDB structure '2m0m'...
# Downloading PDB structure '2m5j'...
# Downloading PDB structure '2mmb'...
# Downloading PDB structure '2nbh'...
# Downloading PDB structure '2pp4'...
# Downloading PDB structure '2xxs'...
# Downloading PDB structure '4crp'...
# Downloading PDB structure '5oun'...
# Downloading PDB structure '6sly'...
# Downloading PDB structure '1aot'...
# Downloading PDB structure '1apc'...
# Downloading PDB structure '1g7d'...
# Downloading PDB structure '1gpx'...
# Downloading PDB structure '1pcp'...
# Downloading PDB structure '1x4x'...
# Downloading PDB structure '2djm'...
# Downloading PDB structure '2jod'...
# Downloading PDB structure '2jox'...
# Downloading PDB structure '2jw5'...
# Downloading PDB structure '2jx9'...
# Downloading PDB structure '2k75'...
# Downloading PDB structure '2k7r'...
# Downloading PDB structure '2k9k'...
# Downloading PDB structure '2khv'...
# Downloading PDB structure '2lfv'...
# Downloading PDB structure '2m19'...
# Downloading PDB structure '2m1z'...
# Downloading PDB structure '2m9h'...
# Downloading PDB structure '2mao'...
# Downloading PDB structure '2n01'...
# Downloading PDB structure '2rn4'...
# Downloading PDB structure '4aka'...
# Downloading PDB structure '4b8t'...
# Downloading PDB structure '5jyt'...
# Downloading PDB structure '1g84'...
# Downloading PDB structure '1ght'...
# Downloading PDB structure '1n5h'...
# Downloading PDB structure '1n6z'...
# Downloading PDB structure '1t4y'...
# Downloading PDB structure '1uhu'...
# Downloading PDB structure '2eqx'...
# Downloading PDB structure '2jn9'...
# Downloading PDB structure '2jps'...
# Downloading PDB structure '2k5f'...
# Downloading PDB structure '2k5q'...
# Downloading PDB structure '2kmt'...
# Downloading PDB structure '2kpm'...
# Downloading PDB structure '2l7u'...
# Downloading PDB structure '2l8y'...
# Downloading PDB structure '2lme'...
# Downloading PDB structure '2lu3'...
# Downloading PDB structure '2m4i'...
# Downloading PDB structure '2mkl'...
# Downloading PDB structure '2mqc'...
# Downloading PDB structure '2n7p'...
# Downloading PDB structure '2v37'...
# Downloading PDB structure '2ysr'...
# Downloading PDB structure '5vwl'...
# Downloading PDB structure '6cjz'...
# Downloading PDB structure '6m3a'...
# Downloading PDB structure '7mu9'...
# Downloading PDB structure '1ck2'...
# Downloading PDB structure '1iyy'...
# Downloading PDB structure '1jrm'...
# Downloading PDB structure '1kvn'...
# Downloading PDB structure '1o0p'...
# Downloading PDB structure '1qqi'...
# Downloading PDB structure '1we8'...
# Downloading PDB structure '1wex'...
# Downloading PDB structure '1wfy'...
# Downloading PDB structure '1whu'...
# Downloading PDB structure '1wi8'...
# Downloading PDB structure '1wj7'...
# Downloading PDB structure '1wz0'...
# Downloading PDB structure '1y4o'...
# Downloading PDB structure '2ctk'...
# Downloading PDB structure '2ctt'...
# Downloading PDB structure '2d1u'...
# Downloading PDB structure '2dhg'...
# Downloading PDB structure '2dhx'...
# Downloading PDB structure '2dle'...
# Downloading PDB structure '2doa'...
# Downloading PDB structure '2gtv'...
# Downloading PDB structure '2jna'...
# Downloading PDB structure '2k0m'...
# Downloading PDB structure '2kna'...
# Downloading PDB structure '2l3n'...
# Downloading PDB structure '2laa'...
# Downloading PDB structure '2ll0'...
# Downloading PDB structure '2lnv'...
# Downloading PDB structure '2m0r'...
# Downloading PDB structure '2n56'...
# Downloading PDB structure '2n8w'...
# Downloading PDB structure '2rvj'...
# Downloading PDB structure '2xc7'...
# Downloading PDB structure '5frg'...
# Downloading PDB structure '7b2b'...
# Downloading PDB structure '8ajr'...
# Downloading PDB structure '1ag4'...
# Downloading PDB structure '1s79'...
# Downloading PDB structure '1s7a'...
# Downloading PDB structure '1te7'...
# Downloading PDB structure '1v5l'...
# Downloading PDB structure '1wcr'...
# Downloading PDB structure '2cqi'...
# Downloading PDB structure '2cu1'...
# Downloading PDB structure '2czn'...
# Downloading PDB structure '2dbg'...
# Downloading PDB structure '2dl9'...
# Downloading PDB structure '2e8o'...
# Downloading PDB structure '2eqn'...
# Downloading PDB structure '2evn'...
# Downloading PDB structure '2k13'...
# Downloading PDB structure '2m87'...
# Downloading PDB structure '2mca'...
# Downloading PDB structure '2mhp'...
# Downloading PDB structure '2rm4'...
# Downloading PDB structure '5lkn'...
# Downloading PDB structure '5zuz'...
# Downloading PDB structure '1bhu'...
# Downloading PDB structure '1cww'...
# Downloading PDB structure '1g10'...
# Downloading PDB structure '1jjg'...
# Downloading PDB structure '1m42'...
# Downloading PDB structure '1r57'...
# Downloading PDB structure '1ss6'...
# Downloading PDB structure '1w0b'...
# Downloading PDB structure '1ywx'...
# Downloading PDB structure '2da6'...
# Downloading PDB structure '2dbh'...
# Downloading PDB structure '2dk6'...
# Downloading PDB structure '2ff0'...
# Downloading PDB structure '2ghf'...
# Downloading PDB structure '2ida'...
# Downloading PDB structure '2job'...
# Downloading PDB structure '2jua'...
# Downloading PDB structure '2k3g'...
# Downloading PDB structure '2kgj'...
# Downloading PDB structure '2kkx'...
# Downloading PDB structure '2km7'...
# Downloading PDB structure '2kmc'...
# Downloading PDB structure '2kou'...
# Downloading PDB structure '2kt7'...
# Downloading PDB structure '2l50'...
# Downloading PDB structure '2l6a'...
# Downloading PDB structure '2l9f'...
# Downloading PDB structure '2m5v'...
# Downloading PDB structure '2mct'...
# Downloading PDB structure '2mqg'...
# Downloading PDB structure '2ms7'...
# Downloading PDB structure '2nco'...
# Downloading PDB structure '5ml1'...
# Downloading PDB structure '6qbi'...
# Downloading PDB structure '1hhn'...
# Downloading PDB structure '1qsv'...
# Downloading PDB structure '1v32'...
# Downloading PDB structure '1v63'...
# Downloading PDB structure '2do7'...
# Downloading PDB structure '2h7d'...
# Downloading PDB structure '2jon'...
# Downloading PDB structure '2jun'...
# Downloading PDB structure '2k5h'...
# Downloading PDB structure '2kjv'...
# Downloading PDB structure '2kwa'...
# Downloading PDB structure '2lf6'...
# Downloading PDB structure '2luw'...
# Downloading PDB structure '2mjm'...
# Downloading PDB structure '2n5g'...
# Downloading PDB structure '2ov6'...
# Downloading PDB structure '2rrd'...
# Downloading PDB structure '6fw4'...
# Downloading PDB structure '1dbd'...
# Downloading PDB structure '1j0f'...
# Downloading PDB structure '1jbi'...
# Downloading PDB structure '1rf8'...
# Downloading PDB structure '1uh6'...
# Downloading PDB structure '1wgr'...
# Downloading PDB structure '1whd'...
# Downloading PDB structure '1whv'...
# Downloading PDB structure '1wju'...
# Downloading PDB structure '1x3a'...
# Downloading PDB structure '2cql'...
# Downloading PDB structure '2d9o'...
# Downloading PDB structure '2dn8'...
# Downloading PDB structure '2do4'...
# Downloading PDB structure '2dzm'...
# Downloading PDB structure '2e2z'...
# Downloading PDB structure '2efi'...
# Downloading PDB structure '2ep8'...
# Downloading PDB structure '2gaq'...
# Downloading PDB structure '2j4m'...
# Downloading PDB structure '2kdg'...
# Downloading PDB structure '2kpq'...
# Downloading PDB structure '2kre'...
# Downloading PDB structure '2kxy'...
# Downloading PDB structure '2l7p'...
# Downloading PDB structure '2lgv'...
# Downloading PDB structure '2llz'...
# Downloading PDB structure '2lz0'...
# Downloading PDB structure '2mzt'...
# Downloading PDB structure '2n9p'...
# Downloading PDB structure '2yre'...
# Downloading PDB structure '3crd'...
# Downloading PDB structure '5o2p'...
# Downloading PDB structure '6h0j'...
# Downloading PDB structure '7m5t'...
# Downloading PDB structure '7qri'...
# Downloading PDB structure '8au4'...
# Downloading PDB structure '8bxj'...
# Downloading PDB structure '1bve'...
# Downloading PDB structure '1exe'...
# Downloading PDB structure '1hv2'...
# Downloading PDB structure '1j2m'...
# Downloading PDB structure '1kat'...
# Downloading PDB structure '1t6w'...
# Downloading PDB structure '1tkw'...
# Downloading PDB structure '1wa8'...
# Downloading PDB structure '1wwu'...
# Downloading PDB structure '2cpd'...
# Downloading PDB structure '2d8r'...
# Downloading PDB structure '2dnw'...
# Downloading PDB structure '2ezl'...
# Downloading PDB structure '2kbz'...
# Downloading PDB structure '2kcl'...
# Downloading PDB structure '2kjg'...
# Downloading PDB structure '2krc'...
# Downloading PDB structure '2l49'...
# Downloading PDB structure '2liu'...
# Downloading PDB structure '2lna'...
# Downloading PDB structure '2lon'...
# Downloading PDB structure '2lsi'...
# Downloading PDB structure '2m4l'...
# Downloading PDB structure '2mzs'...
# Downloading PDB structure '2ndp'...
# Downloading PDB structure '2noc'...
# Downloading PDB structure '2pfu'...
# Downloading PDB structure '5wah'...
# Downloading PDB structure '6ewv'...
# Downloading PDB structure '6kcz'...
# Downloading PDB structure '1beg'...
# Downloading PDB structure '1cyu'...
# Downloading PDB structure '1iv0'...
# Downloading PDB structure '1jdq'...
# Downloading PDB structure '1q1o'...
# Downloading PDB structure '1y7q'...
# Downloading PDB structure '2crl'...
# Downloading PDB structure '2dip'...
# Downloading PDB structure '2dir'...
# Downloading PDB structure '2e5s'...
# Downloading PDB structure '2k19'...
# Downloading PDB structure '2l3u'...
# Downloading PDB structure '2lru'...
# Downloading PDB structure '2lvw'...
# Downloading PDB structure '2mcd'...
# Downloading PDB structure '2wgo'...
# Downloading PDB structure '4ca9'...
# Downloading PDB structure '5k57'...
# Downloading PDB structure '6ehz'...
# Downloading PDB structure '6o0i'...
# Structure exists: '/content/target directory/pdb7csq.ent'
# Downloading PDB structure '7wbn'...
# Downloading PDB structure '1hs7'...
# Downloading PDB structure '1hze'...
# Downloading PDB structure '1m9g'...
# Downloading PDB structure '1y9x'...
# Downloading PDB structure '2d8c'...
# Downloading PDB structure '2dl0'...
# Downloading PDB structure '2ebw'...
# Downloading PDB structure '2hfv'...
# Downloading PDB structure '2hgf'...
# Downloading PDB structure '2jn6'...
# Downloading PDB structure '2k5r'...
# Downloading PDB structure '2kbi'...
# Downloading PDB structure '2kg7'...
# Structure exists: '/content/target directory/pdb2kg7.ent'
# Downloading PDB structure '2kj6'...
# Downloading PDB structure '2l08'...
# Downloading PDB structure '2l0c'...
# Downloading PDB structure '2lq7'...
# Downloading PDB structure '2lwp'...
# Downloading PDB structure '2n7d'...
# Downloading PDB structure '6msp'...
# Downloading PDB structure '6vrj'...
# Downloading PDB structure '1esx'...
# Downloading PDB structure '1i1s'...
# Downloading PDB structure '1n88'...
# Downloading PDB structure '1slj'...
# Downloading PDB structure '1wgg'...
# Downloading PDB structure '1wie'...
# Downloading PDB structure '1wx8'...
# Downloading PDB structure '1ywl'...
# Downloading PDB structure '2d9i'...
# Downloading PDB structure '2e44'...
# Downloading PDB structure '2ens'...
# Downloading PDB structure '2gtj'...
# Downloading PDB structure '2joy'...
# Downloading PDB structure '2kpu'...
# Downloading PDB structure '2kqf'...
# Downloading PDB structure '2lyy'...
# Downloading PDB structure '2mfi'...
# Downloading PDB structure '2mut'...
# Downloading PDB structure '2z4d'...
# Downloading PDB structure '6ib6'...
# Downloading PDB structure '7cnf'...
# Downloading PDB structure '1h5p'...
# Downloading PDB structure '1hk6'...
# Downloading PDB structure '1i35'...
# Downloading PDB structure '1nq4'...
# Downloading PDB structure '1om2'...
# Downloading PDB structure '1ozo'...
# Downloading PDB structure '1ug2'...
# Downloading PDB structure '1v6e'...
# Downloading PDB structure '1vfi'...
# Structure exists: '/content/target directory/pdb1wa8.ent'
# Downloading PDB structure '1xsx'...
# Downloading PDB structure '2ckn'...
# Downloading PDB structure '2ee9'...
# Downloading PDB structure '2fnb'...
# Downloading PDB structure '2jsx'...
# Downloading PDB structure '2k1m'...
# Downloading PDB structure '2kk4'...
# Downloading PDB structure '2kkh'...
# Downloading PDB structure '2kxg'...
# Downloading PDB structure '2l76'...
# Downloading PDB structure '2lpd'...
# Downloading PDB structure '2m3d'...
# Downloading PDB structure '2mda'...
# Downloading PDB structure '2mhj'...
# Downloading PDB structure '2mjf'...
# Downloading PDB structure '2mq0'...
# Downloading PDB structure '2n00'...
# Downloading PDB structure '2n4o'...
# Downloading PDB structure '2n81'...
# Downloading PDB structure '2ofq'...
# Downloading PDB structure '2yu3'...
# Downloading PDB structure '5o57'...
# Downloading PDB structure '5ogu'...
# Downloading PDB structure '6acv'...
# Downloading PDB structure '6izg'...
# Downloading PDB structure '1b75'...
# Downloading PDB structure '1ehx'...
# Downloading PDB structure '1o8r'...
# Downloading PDB structure '1re6'...
# Downloading PDB structure '1wim'...
# Downloading PDB structure '2cpm'...
# Downloading PDB structure '2e5k'...
# Downloading PDB structure '2hwt'...
# Downloading PDB structure '2jr5'...
# Downloading PDB structure '2kan'...
# Downloading PDB structure '2kd2'...
# Downloading PDB structure '2krx'...
# Downloading PDB structure '2kzs'...
# Downloading PDB structure '2l9s'...
# Downloading PDB structure '2ld7'...
# Downloading PDB structure '2lqj'...
# Downloading PDB structure '2lvx'...
# Downloading PDB structure '2n67'...
# Downloading PDB structure '2rnz'...
# Downloading PDB structure '5jtk'...
# Downloading PDB structure '5sxy'...
# Downloading PDB structure '1j8i'...
# Downloading PDB structure '1pcn'...
# Downloading PDB structure '1uhr'...
# Downloading PDB structure '1wgd'...
# Downloading PDB structure '2cqh'...
# Downloading PDB structure '2cto'...
# Downloading PDB structure '2m9k'...
# Downloading PDB structure '5y4b'...
# Downloading PDB structure '6qbl'...
# Downloading PDB structure '6tkt'...
# Downloading PDB structure '6trp'...
# Downloading PDB structure '6ytc'...
# Downloading PDB structure '7omk'...
# Downloading PDB structure '8wwx'...
# Downloading PDB structure '1dz7'...
# Downloading PDB structure '1l5c'...
# Downloading PDB structure '1ug1'...
# Downloading PDB structure '1wh9'...
# Downloading PDB structure '1whm'...
# Downloading PDB structure '1x4t'...
# Downloading PDB structure '2e8p'...
# Downloading PDB structure '2g0u'...
# Downloading PDB structure '2khp'...
# Downloading PDB structure '2kwq'...
# Downloading PDB structure '2mni'...
# Downloading PDB structure '2mxw'...
# Downloading PDB structure '2n2y'...
# Downloading PDB structure '2rrn'...
# Downloading PDB structure '3ncm'...
# Downloading PDB structure '5gqs'...
# Downloading PDB structure '5odd'...
# Downloading PDB structure '6aly'...
# Downloading PDB structure '6k7w'...
# Downloading PDB structure '6pqt'...
# Downloading PDB structure '1f6v'...
# Downloading PDB structure '1m5z'...
# Downloading PDB structure '1pqx'...
# Downloading PDB structure '1weu'...
# Downloading PDB structure '1xee'...
# Downloading PDB structure '1xhh'...
# Downloading PDB structure '1xs8'...
# Downloading PDB structure '2dnr'...
# Downloading PDB structure '2jm3'...
# Downloading PDB structure '2joq'...
# Downloading PDB structure '2kuo'...
# Downloading PDB structure '2kz5'...
# Downloading PDB structure '2l0b'...
# Downloading PDB structure '2lxi'...
# Downloading PDB structure '2my6'...
# Downloading PDB structure '1hqi'...
# Downloading PDB structure '1ily'...
# Downloading PDB structure '1u2f'...
# Downloading PDB structure '1zza'...
# Downloading PDB structure '2d99'...
# Downloading PDB structure '2dar'...
# Downloading PDB structure '2g1e'...
# Downloading PDB structure '2j8j'...
# Downloading PDB structure '2knj'...
# Downloading PDB structure '2kxj'...
# Downloading PDB structure '2lgy'...
# Downloading PDB structure '2lw3'...
# Downloading PDB structure '2mj6'...
# Downloading PDB structure '2mk6'...
# Downloading PDB structure '2n5h'...
# Downloading PDB structure '2n9v'...
# Downloading PDB structure '2ot2'...
# Downloading PDB structure '2yuk'...
# Downloading PDB structure '5t82'...
# Downloading PDB structure '6ob1'...
# Downloading PDB structure '6vwb'...
# Downloading PDB structure '7pq4'...
# Downloading PDB structure '7sxb'...
# Downloading PDB structure '8ept'...
# Downloading PDB structure '1i42'...
# Downloading PDB structure '1lkn'...
# Downloading PDB structure '1vd2'...
# Downloading PDB structure '1wil'...
# Downloading PDB structure '2d9d'...
# Downloading PDB structure '2juo'...
# Downloading PDB structure '2khe'...
# Downloading PDB structure '2ko6'...
# Downloading PDB structure '2kr5'...
# Downloading PDB structure '2ly3'...
# Downloading PDB structure '2m9u'...
# Downloading PDB structure '2mc4'...
# Downloading PDB structure '2png'...
# Downloading PDB structure '2wbr'...
# Downloading PDB structure '2yqm'...
# Downloading PDB structure '5izb'...
# Downloading PDB structure '5wyo'...
# Downloading PDB structure '6cgh'...
# Downloading PDB structure '7zk0'...
# Downloading PDB structure '8j3n'...
# Downloading PDB structure '1e08'...
# Downloading PDB structure '1emw'...
# Downloading PDB structure '1heh'...
# Downloading PDB structure '1imo'...
# Downloading PDB structure '1iur'...
# Downloading PDB structure '1ka5'...
# Downloading PDB structure '1ujs'...
# Downloading PDB structure '1uss'...
# Downloading PDB structure '1wg1'...
# Downloading PDB structure '1wkt'...
# Downloading PDB structure '1xhj'...
# Downloading PDB structure '1z8m'...
# Downloading PDB structure '2ct2'...
# Downloading PDB structure '2dzj'...
# Downloading PDB structure '2elj'...
# Downloading PDB structure '2ko1'...
# Downloading PDB structure '2ld3'...
# Downloading PDB structure '2lr6'...
# Downloading PDB structure '2ma3'...
# Downloading PDB structure '2mnj'...
# Downloading PDB structure '2mtl'...
# Downloading PDB structure '2mv3'...
# Downloading PDB structure '2rqp'...
# Downloading PDB structure '2u1a'...
# Downloading PDB structure '2vxe'...
# Downloading PDB structure '4bwh'...
# Downloading PDB structure '6kqv'...
# Downloading PDB structure '1a6x'...
# Downloading PDB structure '1c6s'...
# Downloading PDB structure '1de1'...
# Downloading PDB structure '1f2r'...
# Downloading PDB structure '1g6e'...
# Downloading PDB structure '1k5k'...
# Downloading PDB structure '1m62'...
# Downloading PDB structure '1r05'...
# Downloading PDB structure '1rhx'...
# Downloading PDB structure '1sb0'...
# Downloading PDB structure '1ug8'...
# Downloading PDB structure '1z6c'...
# Downloading PDB structure '2e6o'...
# Downloading PDB structure '2fho'...
# Downloading PDB structure '2gva'...
# Downloading PDB structure '2jz8'...
# Downloading PDB structure '2k3d'...
# Downloading PDB structure '2kyw'...
# Downloading PDB structure '2lml'...
# Downloading PDB structure '2lyx'...
# Downloading PDB structure '2m45'...
# Downloading PDB structure '2nch'...
# Downloading PDB structure '2rpr'...
# Downloading PDB structure '2v0f'...
# Downloading PDB structure '5xn4'...
# Downloading PDB structure '7mp7'...
# Downloading PDB structure '1e0h'...
# Downloading PDB structure '1g4f'...
# Downloading PDB structure '1noe'...
# Downloading PDB structure '1sg5'...
# Downloading PDB structure '1sse'...
# Downloading PDB structure '1wfe'...
# Downloading PDB structure '1whe'...
# Downloading PDB structure '1x6h'...
# Downloading PDB structure '2c7h'...
# Downloading PDB structure '2dk3'...
# Downloading PDB structure '2ebi'...
# Downloading PDB structure '2fe9'...
# Downloading PDB structure '2jxb'...
# Downloading PDB structure '2jxt'...
# Downloading PDB structure '2k3v'...
# Downloading PDB structure '2kqp'...
# Downloading PDB structure '2mmv'...
# Downloading PDB structure '2n5n'...
# Downloading PDB structure '2uwq'...
# Downloading PDB structure '4d7x'...
# Downloading PDB structure '5m0a'...
# Downloading PDB structure '5syq'...
# Downloading PDB structure '6ffq'...
# Downloading PDB structure '6zss'...
# Downloading PDB structure '7ne8'...
# Downloading PDB structure '7tuj'...
# Downloading PDB structure '7x31'...
# Downloading PDB structure '8aig'...
# Downloading PDB structure '1cou'...
# Downloading PDB structure '1ip9'...
# Downloading PDB structure '1j46'...
# Downloading PDB structure '1uqv'...
# Downloading PDB structure '1wii'...
# Downloading PDB structure '1ysy'...
# Downloading PDB structure '2auv'...
# Downloading PDB structure '2dkl'...
# Downloading PDB structure '2dlp'...
# Downloading PDB structure '2dof'...
# Downloading PDB structure '2dog'...
# Downloading PDB structure '2eli'...
# Downloading PDB structure '2eqk'...
# Downloading PDB structure '2jov'...
# Downloading PDB structure '2jtq'...
# Downloading PDB structure '2krh'...
# Downloading PDB structure '2kt6'...
# Downloading PDB structure '2l48'...
# Downloading PDB structure '2mdp'...
# Downloading PDB structure '2ns5'...
# Downloading PDB structure '5b88'...
# Downloading PDB structure '5t17'...
# Downloading PDB structure '6fwn'...
# Downloading PDB structure '6gf2'...
# Downloading PDB structure '7z3c'...
# Downloading PDB structure '1f53'...
# Downloading PDB structure '1iio'...
# Downloading PDB structure '1l1i'...
# Downloading PDB structure '1m12'...
# Downloading PDB structure '1r79'...
# Downloading PDB structure '1ufm'...
# Downloading PDB structure '1z00'...
# Downloading PDB structure '2cqw'...
# Downloading PDB structure '2dkz'...
# Downloading PDB structure '2fft'...
# Downloading PDB structure '2heq'...
# Downloading PDB structure '2kk8'...
# Downloading PDB structure '2kt0'...
# Downloading PDB structure '2l27'...
# Downloading PDB structure '2mt3'...
# Downloading PDB structure '2n2t'...
# Downloading PDB structure '2n5d'...
# Downloading PDB structure '2row'...
# Downloading PDB structure '5abk'...
# Downloading PDB structure '6oh1'...
# Downloading PDB structure '6zop'...
# Downloading PDB structure '7ywr'...
# Downloading PDB structure '8e4v'...
# Downloading PDB structure '1dhm'...
# Downloading PDB structure '1se7'...
# Downloading PDB structure '1ufz'...
# Downloading PDB structure '1wge'...
# Downloading PDB structure '2an7'...
# Downloading PDB structure '2dmn'...
# Downloading PDB structure '2ean'...
# Downloading PDB structure '2jpq'...
# Downloading PDB structure '2kz3'...
# Downloading PDB structure '2l1s'...
# Downloading PDB structure '2ln3'...
# Downloading PDB structure '2m6m'...
# Downloading PDB structure '2mop'...
# Downloading PDB structure '2rvl'...
# Downloading PDB structure '7qab'...
# Downloading PDB structure '7ze0'...
# Desired structure doesn't exist
# Downloading PDB structure '8all'...
# Downloading PDB structure '1cor'...
# Downloading PDB structure '2a02'...
# Downloading PDB structure '2fc7'...
# Downloading PDB structure '2fj6'...
# Downloading PDB structure '2fmc'...
# Downloading PDB structure '2hzd'...
# Downloading PDB structure '2kon'...
# Downloading PDB structure '2l02'...
# Downloading PDB structure '2l3a'...
# Downloading PDB structure '2ljm'...
# Downloading PDB structure '2mew'...
# Downloading PDB structure '2muy'...
# Downloading PDB structure '2mx0'...
# Downloading PDB structure '2nrg'...
# Downloading PDB structure '5o6f'...
# Downloading PDB structure '6qeu'...
# Downloading PDB structure '6zze'...
# Downloading PDB structure '7rz3'...
# Downloading PDB structure '1d8b'...
# Downloading PDB structure '1dcj'...
# Downloading PDB structure '1ghh'...
# Downloading PDB structure '1gjx'...
# Downloading PDB structure '1kx2'...
# Downloading PDB structure '1o6x'...
# Downloading PDB structure '1rip'...
# Downloading PDB structure '1urf'...
# Downloading PDB structure '1x43'...
# Downloading PDB structure '2d7l'...
# Downloading PDB structure '2fh0'...
# Downloading PDB structure '2htj'...
# Downloading PDB structure '2jz7'...
# Downloading PDB structure '2kub'...
# Downloading PDB structure '2lkl'...
# Downloading PDB structure '2lpb'...
# Downloading PDB structure '2lxc'...
# Downloading PDB structure '2m67'...
# Downloading PDB structure '2m7z'...
# Downloading PDB structure '2mx2'...
# Downloading PDB structure '2ncl'...
# Downloading PDB structure '5n9v'...
# Downloading PDB structure '5zmb'...
# Downloading PDB structure '6mwm'...
# Downloading PDB structure '6tey'...
# Downloading PDB structure '6u6p'...
# Downloading PDB structure '8v9u'...
# Downloading PDB structure '1dv5'...
# Downloading PDB structure '1hj7'...
# Downloading PDB structure '1imt'...
# Downloading PDB structure '1jww'...
# Downloading PDB structure '1k0t'...
# Downloading PDB structure '1pmr'...
# Downloading PDB structure '1xu6'...
# Downloading PDB structure '2cue'...
# Downloading PDB structure '2js1'...
# Downloading PDB structure '2jvm'...
# Downloading PDB structure '2jz1'...
# Downloading PDB structure '2k5j'...
# Downloading PDB structure '2k89'...
# Downloading PDB structure '2k9p'...
# Downloading PDB structure '2kbq'...
# Downloading PDB structure '2kvs'...
# Downloading PDB structure '2l95'...
# ...
# Downloading PDB structure '1zhc'...
# Downloading PDB structure '2djr'...
# Downloading PDB structure '2jub'...
# Downloading PDB structure '2kt8'...
# Downloading PDB structure '2l7k'...
# Downloading PDB structure '2lxr'...
# Downloading PDB structure '2m3l'...
# Downloading PDB structure '2n6r'...
# Downloading PDB structure '2n8k'...
# Downloading PDB structure '6yhz'...
# Downloading PDB structure '6yi2'...
# Downloading PDB structure '7lu8'...
# Downloading PDB structure '7luw'...
# Downloading PDB structure '7mzx'...
# Downloading PDB structure '1ghc'...
# Downloading PDB structure '1iie'...
# Downloading PDB structure '1ksq'...
# Downloading PDB structure '1s4z'...
# Downloading PDB structure '2dae'...
# Downloading PDB structure '2ezi'...
# Structure exists: '/content/target directory/pdb2ld7.ent'
# Downloading PDB structure '2ln8'...
# Downloading PDB structure '2ma1'...
# Downloading PDB structure '2mhg'...
# Downloading PDB structure '2myx'...
# Downloading PDB structure '5l85'...
# Downloading PDB structure '6h0i'...
# Downloading PDB structure '7ac1'...
# Downloading PDB structure '1dqc'...
# Downloading PDB structure '1kjs'...
# Downloading PDB structure '1neq'...
# Downloading PDB structure '1th5'...
# Downloading PDB structure '1wfw'...
# Downloading PDB structure '1ywy'...
# Downloading PDB structure '2akk'...
# Downloading PDB structure '2b9z'...
# Downloading PDB structure '2jnj'...
# Downloading PDB structure '2jwk'...
# Downloading PDB structure '2k5n'...
# Downloading PDB structure '2kcm'...
# Downloading PDB structure '2kcx'...
# Downloading PDB structure '2lxb'...
# Downloading PDB structure '2ly9'...
# Downloading PDB structure '2mpk'...
# Downloading PDB structure '2n11'...
# Structure exists: '/content/target directory/pdb2n1t.ent'
# Downloading PDB structure '2yra'...
# Downloading PDB structure '6ba3'...
# Downloading PDB structure '6tj3'...
# Downloading PDB structure '6to6'...
# Downloading PDB structure '1bo9'...
# Downloading PDB structure '1mgs'...
# Downloading PDB structure '1pih'...
# Downloading PDB structure '1rjt'...
# Downloading PDB structure '1vg5'...
# Downloading PDB structure '1wgx'...
# Downloading PDB structure '2k5e'...
# Downloading PDB structure '2k5s'...
# Downloading PDB structure '2kmm'...
# Downloading PDB structure '2l2d'...
# Downloading PDB structure '2rts'...
# Downloading PDB structure '5ktf'...
# Downloading PDB structure '5oeo'...
# Downloading PDB structure '7pku'...
# Downloading PDB structure '1pve'...
# Downloading PDB structure '1wi9'...
# Downloading PDB structure '2adl'...
# Downloading PDB structure '2csv'...
# Downloading PDB structure '2j2s'...
# Downloading PDB structure '2j5o'...
# Downloading PDB structure '2jo1'...
# Downloading PDB structure '2jvg'...
# Downloading PDB structure '2jye'...
# Downloading PDB structure '2k6x'...
# Downloading PDB structure '6txt'...
# Downloading PDB structure '1adz'...
# Downloading PDB structure '1ajy'...
# Downloading PDB structure '1bbi'...
# Downloading PDB structure '1daq'...
# Downloading PDB structure '1k3g'...
# Downloading PDB structure '1vig'...
# Downloading PDB structure '2cqj'...
# Downloading PDB structure '2da7'...
# Downloading PDB structure '2e70'...
# Downloading PDB structure '2js5'...
# Downloading PDB structure '2kdp'...
# Downloading PDB structure '2kis'...
# Downloading PDB structure '2ksk'...
# Downloading PDB structure '2kvt'...
# Downloading PDB structure '2l8t'...
# Downloading PDB structure '2ltf'...
# Downloading PDB structure '2lzz'...
# Downloading PDB structure '3zbe'...
# Downloading PDB structure '3zj2'...
# Downloading PDB structure '5nhq'...
# Downloading PDB structure '6xor'...
# Downloading PDB structure '1dwm'...
# Downloading PDB structure '1e68'...
# Downloading PDB structure '1fgp'...
# Downloading PDB structure '1q1v'...
# Downloading PDB structure '1qp2'...
# Downloading PDB structure '1yvc'...
# Downloading PDB structure '2cob'...
# Downloading PDB structure '2coo'...
# Downloading PDB structure '2gqc'...
# Downloading PDB structure '2lww'...
# Downloading PDB structure '2mh3'...
# Downloading PDB structure '2n34'...
# Downloading PDB structure '2ru1'...
# Downloading PDB structure '6evi'...
# Downloading PDB structure '6y8v'...
# Downloading PDB structure '1bby'...
# Downloading PDB structure '1bfm'...
# Downloading PDB structure '1go5'...
# Downloading PDB structure '1l6h'...
# Downloading PDB structure '1ryk'...
# Downloading PDB structure '1u96'...
# Downloading PDB structure '2dy8'...
# Downloading PDB structure '2e61'...
# Downloading PDB structure '2jx5'...
# Downloading PDB structure '2kz9'...
# Downloading PDB structure '2lbf'...
# Downloading PDB structure '2m1l'...
# Downloading PDB structure '2mfk'...
# Structure exists: '/content/target directory/pdb2n1t.ent'
# Downloading PDB structure '2n72'...
# Downloading PDB structure '4ull'...
# Downloading PDB structure '1bmr'...
# Downloading PDB structure '1j9i'...
# Downloading PDB structure '1ne3'...
# Downloading PDB structure '2ea5'...
# Downloading PDB structure '2jr6'...
# Downloading PDB structure '2kn8'...
# Downloading PDB structure '2kw3'...
# Downloading PDB structure '2lfh'...
# Downloading PDB structure '2lzf'...
# Downloading PDB structure '2mpn'...
# Downloading PDB structure '2rm8'...
# Downloading PDB structure '2rsd'...
# Downloading PDB structure '5o9b'...
# Downloading PDB structure '6obi'...
# Downloading PDB structure '6z41'...
# Downloading PDB structure '7k3s'...
# Downloading PDB structure '7lp5'...
# Downloading PDB structure '1dtv'...
# Downloading PDB structure '1joy'...
# Downloading PDB structure '1tba'...
# Downloading PDB structure '2jra'...
# Downloading PDB structure '2k7l'...
# Downloading PDB structure '2kyz'...
# Downloading PDB structure '2mrn'...
# Downloading PDB structure '2x43'...
# Downloading PDB structure '7c1m'...
# Downloading PDB structure '7vbg'...
# Downloading PDB structure '8wt5'...
# Downloading PDB structure '1cop'...
# Downloading PDB structure '1f0z'...
# Downloading PDB structure '1owt'...
# Downloading PDB structure '1r73'...
# Downloading PDB structure '1x4p'...
# Downloading PDB structure '1z4h'...
# Downloading PDB structure '2bzt'...
# Downloading PDB structure '2eod'...
# Downloading PDB structure '2l8d'...
# Downloading PDB structure '2lgn'...
# Downloading PDB structure '2m7k'...
# Downloading PDB structure '2mg4'...
# Downloading PDB structure '2n37'...
# Downloading PDB structure '2phe'...
# Downloading PDB structure '2yt5'...
# Downloading PDB structure '7p2o'...
# Downloading PDB structure '1f4s'...
# Downloading PDB structure '1gjs'...
# Downloading PDB structure '1l3h'...
# Downloading PDB structure '1v66'...
# Downloading PDB structure '2jtv'...
# Downloading PDB structure '2kjx'...
# Downloading PDB structure '2lnh'...
# Downloading PDB structure '2m13'...
# Downloading PDB structure '2mm2'...
# Downloading PDB structure '5xjk'...
# Downloading PDB structure '1dax'...
# Downloading PDB structure '1ry3'...
# Downloading PDB structure '1sb6'...
# Downloading PDB structure '1sq8'...
# Downloading PDB structure '1vf9'...
# Downloading PDB structure '2c0s'...
# Downloading PDB structure '2cp9'...
# Downloading PDB structure '2lot'...
# Downloading PDB structure '2mzf'...
# Downloading PDB structure '2wcc'...
# Downloading PDB structure '6trm'...
# Downloading PDB structure '7bwe'...
# Downloading PDB structure '7dab'...
# Downloading PDB structure '1aa3'...
# Downloading PDB structure '1gcc'...
# Downloading PDB structure '1rpr'...
# Downloading PDB structure '1ueo'...
# Downloading PDB structure '1wgn'...
# Downloading PDB structure '2cqf'...
# Downloading PDB structure '2jms'...
# Downloading PDB structure '2l35'...
# Downloading PDB structure '2m6x'...
# Downloading PDB structure '7p3p'...
# Downloading PDB structure '8ap5'...
# Downloading PDB structure '1cjg'...
# Downloading PDB structure '1gyf'...
# Downloading PDB structure '1koy'...
# Downloading PDB structure '1rq6'...
# Downloading PDB structure '1ss1'...
# Downloading PDB structure '1trl'...
# Downloading PDB structure '1x58'...
# Downloading PDB structure '1y76'...
# Downloading PDB structure '2jss'...
# Downloading PDB structure '2kzy'...
# Downloading PDB structure '2l09'...
# Downloading PDB structure '2l6q'...
# Downloading PDB structure '2ltu'...
# Downloading PDB structure '2mxd'...
# Downloading PDB structure '6ydh'...
# Downloading PDB structure '7qjf'...
# Downloading PDB structure '1szl'...
# Downloading PDB structure '1y00'...
# Downloading PDB structure '2d46'...
# Downloading PDB structure '2e62'...
# Downloading PDB structure '2ekf'...
# Downloading PDB structure '2lrd'...
# Downloading PDB structure '2ma6'...
# Downloading PDB structure '2rms'...
# Downloading PDB structure '6tl0'...
# Downloading PDB structure '7uwy'...
# Downloading PDB structure '1bf0'...
# Downloading PDB structure '1gyz'...
# Downloading PDB structure '1hx2'...
# Downloading PDB structure '1kg1'...
# Downloading PDB structure '1nei'...
# Downloading PDB structure '1ng7'...
# Downloading PDB structure '1tap'...
# Structure exists: '/content/target directory/pdb1y76.ent'
# Downloading PDB structure '2g31'...
# Downloading PDB structure '2jtm'...
# Downloading PDB structure '2k88'...
# Downloading PDB structure '2m20'...
# Downloading PDB structure '2nb1'...
# Downloading PDB structure '6q2z'...
# Structure exists: '/content/target directory/pdb7k3s.ent'
# Downloading PDB structure '7uv4'...
# Downloading PDB structure '7zjy'...
# Downloading PDB structure '2b7e'...
# Downloading PDB structure '2c52'...
# Downloading PDB structure '2glo'...
# Downloading PDB structure '2luh'...
# Downloading PDB structure '2n86'...
# Downloading PDB structure '2yrc'...
# Downloading PDB structure '7lxk'...
# Downloading PDB structure '1qa5'...
# Downloading PDB structure '1t50'...
# Downloading PDB structure '1tle'...
# Downloading PDB structure '1y2y'...
# Downloading PDB structure '2mky'...
# Downloading PDB structure '2mm4'...
# Downloading PDB structure '2mwr'...
# Downloading PDB structure '2rup'...
# Downloading PDB structure '1bus'...
# Downloading PDB structure '1h9f'...
# Downloading PDB structure '1x3q'...
# Downloading PDB structure '1y74'...
# Downloading PDB structure '2a05'...
# Downloading PDB structure '2jp7'...
# Downloading PDB structure '2k9h'...
# Downloading PDB structure '2ka4'...
# Downloading PDB structure '2lev'...
# Downloading PDB structure '2lfk'...
# Downloading PDB structure '2lmk'...
# Downloading PDB structure '2mdf'...
# Downloading PDB structure '2mi5'...
# Downloading PDB structure '2n5l'...
# Downloading PDB structure '2ysd'...
# Downloading PDB structure '5oqs'...
# Downloading PDB structure '6lxf'...
# Downloading PDB structure '6urs'...
# Downloading PDB structure '1cqu'...
# Downloading PDB structure '1rso'...
# Downloading PDB structure '2ayj'...
# Downloading PDB structure '2kk9'...
# Downloading PDB structure '2kmu'...
# Downloading PDB structure '6nu4'...
# Downloading PDB structure '1auu'...
# Downloading PDB structure '1clf'...
# Downloading PDB structure '1iw4'...
# Downloading PDB structure '1kmx'...
# Downloading PDB structure '1vib'...
# Downloading PDB structure '2fxp'...
# Downloading PDB structure '2k9i'...
# Downloading PDB structure '2yrk'...
# Downloading PDB structure '7b3j'...
# Downloading PDB structure '2lcy'...
# Downloading PDB structure '2n1d'...
# Downloading PDB structure '6xyv'...
# Downloading PDB structure '1arq'...
# Downloading PDB structure '1qcv'...
# Downloading PDB structure '1r4g'...
# Downloading PDB structure '1z0r'...
# Downloading PDB structure '2did'...
# Downloading PDB structure '2l7s'...
# Downloading PDB structure '2n8p'...
# Downloading PDB structure '7b7o'...
# Downloading PDB structure '1fjk'...
# Downloading PDB structure '1lpv'...
# Downloading PDB structure '1p4q'...
# Downloading PDB structure '1vdi'...
# Downloading PDB structure '2bic'...
# Downloading PDB structure '2ju0'...
# Downloading PDB structure '2jx4'...
# Downloading PDB structure '2lqh'...
# Downloading PDB structure '2lua'...
# Downloading PDB structure '2m35'...
# Downloading PDB structure '2n5m'...
# Downloading PDB structure '1hic'...
# Downloading PDB structure '1l8c'...
# Downloading PDB structure '1udk'...
# Downloading PDB structure '2jo8'...
# Downloading PDB structure '2lw9'...
# Downloading PDB structure '2md0'...
# Downloading PDB structure '6e8w'...
# Downloading PDB structure '1e8r'...
# Downloading PDB structure '1fdm'...
# Downloading PDB structure '1ss3'...
# Downloading PDB structure '1tpm'...
# Downloading PDB structure '1ugl'...
# Structure exists: '/content/target directory/pdb1y74.ent'
# Downloading PDB structure '2ezw'...
# Downloading PDB structure '2kji'...
# Downloading PDB structure '2kyg'...
# Downloading PDB structure '2m76'...
# Downloading PDB structure '2n3x'...
# Downloading PDB structure '6ftk'...
# Downloading PDB structure '7eau'...
# Downloading PDB structure '8ar0'...
# Downloading PDB structure '8ar2'...
# Downloading PDB structure '8ar3'...
# Downloading PDB structure '1h7d'...
# Downloading PDB structure '1shi'...
# Downloading PDB structure '1z6v'...
# Downloading PDB structure '2j8p'...
# Downloading PDB structure '2l8e'...
# Downloading PDB structure '2ndb'...
# Downloading PDB structure '5ij4'...
# Downloading PDB structure '5n7y'...
# Downloading PDB structure '6wql'...
# Downloading PDB structure '8qnt'...
# Downloading PDB structure '1ssl'...
# Downloading PDB structure '2jwh'...
# Downloading PDB structure '2kes'...
# Downloading PDB structure '2ksg'...
# Downloading PDB structure '5nam'...
# Downloading PDB structure '7c4o'...
# Downloading PDB structure '1aq5'...
# Downloading PDB structure '1pgy'...
# Downloading PDB structure '2b9k'...
# Downloading PDB structure '2mw4'...
# Downloading PDB structure '5j8t'...
# Downloading PDB structure '5t42'...
# Downloading PDB structure '7lgl'...
# Downloading PDB structure '1ccm'...
# Downloading PDB structure '1hyk'...
# Downloading PDB structure '1nbl'...
# Downloading PDB structure '1ni8'...
# Downloading PDB structure '1pjf'...
# Downloading PDB structure '2enf'...
# Downloading PDB structure '2imu'...
# Downloading PDB structure '2jry'...
# Downloading PDB structure '2mby'...
# Downloading PDB structure '2mjg'...
# Downloading PDB structure '2mz7'...
# Downloading PDB structure '2ndi'...
# Downloading PDB structure '6mf8'...
# Downloading PDB structure '1g9p'...
# Downloading PDB structure '1jo6'...
# Downloading PDB structure '1kj6'...
# Downloading PDB structure '2j5d'...
# Downloading PDB structure '2jxg'...
# Downloading PDB structure '2ka6'...
# Structure exists: '/content/target directory/pdb2l9s.ent'
# Downloading PDB structure '5x9x'...
# Downloading PDB structure '1cf4'...
# Downloading PDB structure '1cwx'...
# Downloading PDB structure '1jun'...
# Downloading PDB structure '2k9d'...
# Downloading PDB structure '2lb7'...
# Downloading PDB structure '5kgz'...
# Downloading PDB structure '6t33'...
# Downloading PDB structure '7mj3'...
# Downloading PDB structure '1aw6'...
# Downloading PDB structure '1bzk'...
# Downloading PDB structure '2e30'...
# Downloading PDB structure '2ke3'...
# Downloading PDB structure '2kuy'...
# Downloading PDB structure '2l2l'...
# Downloading PDB structure '2lzl'...
# Downloading PDB structure '2n70'...
# Downloading PDB structure '5lme'...
# Downloading PDB structure '6obk'...
# Downloading PDB structure '8imh'...
# Downloading PDB structure '1co4'...
# Downloading PDB structure '1d6b'...
# Downloading PDB structure '1go9'...
# Downloading PDB structure '1kv4'...
# Downloading PDB structure '1qdp'...
# Downloading PDB structure '1ujl'...
# Downloading PDB structure '1wqk'...
# Downloading PDB structure '2b4n'...
# Downloading PDB structure '2lmz'...
# Downloading PDB structure '8bvc'...
# Downloading PDB structure '8um1'...
# Downloading PDB structure '1bi6'...
# Downloading PDB structure '1hj0'...
# Downloading PDB structure '1wt7'...
# Downloading PDB structure '2j5h'...
# Downloading PDB structure '2lqx'...
# Downloading PDB structure '2mic'...
# Downloading PDB structure '2my2'...
# Downloading PDB structure '2myh'...
# Downloading PDB structure '2n85'...
# Downloading PDB structure '4cyk'...
# Downloading PDB structure '6qbj'...
# Downloading PDB structure '6uch'...
# Downloading PDB structure '8ahk'...
# Downloading PDB structure '1edx'...
# Downloading PDB structure '1erc'...
# Downloading PDB structure '1erd'...
# Downloading PDB structure '1hn3'...
# Downloading PDB structure '1m7l'...
# Downloading PDB structure '2koe'...
# Downloading PDB structure '2kwz'...
# Downloading PDB structure '2lg4'...
# Downloading PDB structure '2mrw'...
# Downloading PDB structure '6qjb'...
# Downloading PDB structure '7zro'...

# %% [markdown]
# creating a dictionary of continuous chains

# %%
#we need the chain acces information
pdb_id_map = {pdb_id[:-1]: pdb_id for pdb_id in pdb_ids}
print(pdb_id_map)

mapping_file = os.path.join('/content/map', 'pdb_id_mapping.csv')
#pd.Series(pdb_id_map).to_csv(mapping_file, header=False)
pd.Series({k.lower(): v for k, v in pdb_id_map.items()}).to_csv(mapping_file, header=False) # un capitalising them
# Out:
# {'1E0Z': '1E0ZA', '1RY4': '1RY4A', '1UG7': '1UG7A', '1WHN': '1WHNA', '2AYA': '2AYAA', '2D87': '2D87A', '2DB5': '2DB5A', '2DKP': '2DKPA', '2EBK': '2EBKA', '2ETT': '2ETTA', '2FM4': '2FM4A', '2I4K': '2I4KA', '2JQ5': '2JQ5A', '2K0R': '2K0RA', '2K5T': '2K5TA', '2LR4': '2LR4A', '2LS0': '2LS01', '2LVL': '2LVLA', '2MAH': '2MAHA', '2NCN': '2NCNA', '2RLO': '2RLOA', '2RV8': '2RV8A', '2YTU': '2YTUA', '4AR0': '4AR0A', '5AIW': '5AIWA', '5H7U': '5H7UA', '5N9Q': '5N9QA', '8E22': '8E22X', '1CMO': '1CMOA', '1DDF': '1DDFA', '1EAL': '1EALA', '1PQN': '1PQNA', '1QKL': '1QKLA', '1UEY': '1UEYA', '1W2Q': '1W2QA', '1WH4': '1WH4A', '1WJR': '1WJRA', '1X5M': '1X5MA', '1ZU1': '1ZU1A', '2CSO': '2CSOA', '2DMK': '2DMKA', '2EE7': '2EE7A', '2L1L': '2L1LB', '2LOE': '2LOEA', '2MF7': '2MF7A', '2MPL': '2MPLA', '2NBO': '2NBOA', '2TMP': '2TMPA', '4UEI': '4UEIA', '5M1U': '5M1UA', '7XRW': '7XRWA', '8OIL': '8OILA', '1RSF': '1RSFA', '1V5S': '1V5SA', '1X5E': '1X5EA', '1ZO0': '1ZO0A', '2A4H': '2A4HA', '2CR4': '2CR4A', '2DAV': '2DAVA', '2IF1': '2IF1A', '2JP2': '2JP2A', '2JVN': '2JVNA', '2K2V': '2K2VA', '2L3G': '2L3GA', '2L57': '2L57A', '2LBC': '2LBCA', '2LLN': '2LLNA', '2M26': '2M26A', '3MSP': '3MSPA', '7F7N': '7F7NA', '7KNV': '7KNVA', '8SQX': '8SQXA', '1BUQ': '1BUQA', '1BW3': '1BW3A', '1FR0': '1FR0A', '1GIO': '1GIOA', '1MH6': '1MH6A', '1PSY': '1PSYA', '1UEN': '1UENA', '1WYJ': '1WYJA', '2AI6': '2AI6A', '2DHJ': '2DHJA', '2K4V': '2K4VA', '2K4Z': '2K4ZA', '2KA5': '2KA5A', '2KFP': '2KFPA', '2KYT': '2KYTA', '2L2C': '2L2CA', '2LDU': '2LDUA', '2LM0': '2LM0A', '2MDK': '2MDKA', '2MV4': '2MV4A', '2N2H': '2N2HB', '2NBG': '2NBGA', '2PRF': '2PRFA', '4A53': '4A53A', '5KNW': '5KNWA', '5T3Y': '5T3YA', '5WOE': '5WOEA', '6GWM': '6GWMA', '6TH8': '6TH8A', '6UF2': '6UF2A', '6XEH': '6XEHA', '7BQC': '7BQCA', '7PRD': '7PRDA', '7QYI': '7QYIA', '1DC7': '1DC7A', '1E8E': '1E8EA', '1EO1': '1EO1A', '1PIR': '1PIRA', '1T3V': '1T3VA', '1WEL': '1WELA', '1WGV': '1WGVA', '1WHR': '1WHRA', '1WIS': '1WISA', '1WJ4': '1WJ4A', '1WJO': '1WJOA', '1X52': '1X52A', '2COM': '2COMA', '2CPR': '2CPRA', '2D5U': '2D5UA', '2E5I': '2E5IA', '2JWN': '2JWNA', '2KA0': '2KA0A', '2KIE': '2KIEA', '2KV1': '2KV1A', '2LLI': '2LLIA', '2M4M': '2M4MA', '5UKE': '5UKEA', '5WQZ': '5WQZA', '6S3W': '6S3WA', '6X1K': '6X1KA', '7BPN': '7BPNA', '1QCE': '1QCEA', '1RZW': '1RZWA', '1T2R': '1T2RA', '1TUJ': '1TUJA', '1V60': '1V60A', '1WGO': '1WGOA', '2DAT': '2DATA', '2EDD': '2EDDA', '2GA5': '2GA5A', '2GW6': '2GW6A', '2K2O': '2K2OA', '2K54': '2K54A', '2KSC': '2KSCA', '2LBO': '2LBOA', '2LPM': '2LPMA', '2LVM': '2LVMA', '2M0Q': '2M0QA', '2N3O': '2N3OA', '2P80': '2P80D', '2YQG': '2YQGA', '6NBN': '6NBNA', '8I25': '8I25A', '1AXJ': '1AXJA', '1BIP': '1BIPA', '1D4B': '1D4BA', '1DRO': '1DROA', '1IT4': '1IT4A', '1NR3': '1NR3A', '1PLO': '1PLOA', '1V5Q': '1V5QA', '1YUA': '1YUAA', '2CQM': '2CQMA', '2CRY': '2CRYA', '2EQY': '2EQYA', '2KUT': '2KUTA', '2LFI': '2LFIA', '2LHT': '2LHTA', '2M5Y': '2M5YA', '2MWI': '2MWIA', '2MZN': '2MZNA', '2ROH': '2ROHA', '2YS4': '2YS4A', '5Y7L': '5Y7LA', '6QS0': '6QS0A', '7BQS': '7BQSA', '7S0N': '7S0NA', '1QW1': '1QW1A', '1YZS': '1YZSA', '1Z2F': '1Z2FA', '2D88': '2D88A', '2DLL': '2DLLA', '2EDO': '2EDOA', '2HRJ': '2HRJA', '2KDC': '2KDCA', '2KKV': '2KKVA', '2KRT': '2KRTA', '2LBW': '2LBWA', '2LXF': '2LXFA', '2LY8': '2LY8A', '2MMZ': '2MMZA', '2RQ5': '2RQ5A', '6BYV': '6BYVA', '6F8E': '6F8EA', '7NY0': '7NY0A', '1BR0': '1BR0A', '1MW4': '1MW4A', '1RQU': '1RQUA', '1RYU': '1RYUA', '1WFU': '1WFUA', '1WJ5': '1WJ5A', '1X5F': '1X5FA', '2BO5': '2BO5A', '2CRV': '2CRVA', '2D9X': '2D9XA', '2DHZ': '2DHZA', '2DME': '2DMEA', '2KCD': '2KCDA', '2KOK': '2KOKA', '2KVO': '2KVOA', '2KYM': '2KYMA', '2L1N': '2L1NA', '2L4W': '2L4WA', '2MBL': '2MBLA', '2MHC': '2MHCA', '2YUX': '2YUXA', '5KPE': '5KPEA', '6RPV': '6RPVA', '8FA3': '8FA3A', '1BAK': '1BAKA', '1FHO': '1FHOA', '1JFN': '1JFNA', '1N3J': '1N3JA', '1UJX': '1UJXA', '1W9R': '1W9RA', '1WI5': '1WI5A', '1X0O': '1X0OA', '1X6D': '1X6DA', '1YR1': '1YR1A', '2DB2': '2DB2A', '2J48': '2J48A', '2KDX': '2KDXA', '2KQ1': '2KQ1A', '2LJ ...

# %% [markdown]
# Encoding protein sequences and extracting angles and embeddings into a file for later use

# %%
from Bio.PDB import PDBParser
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

def is_chain_continuous(chain):
    prev_resnum = None
    for residue in chain:
        if prev_resnum is not None and residue.get_id()[1] != prev_resnum + 1:
            return False
        prev_resnum = residue.get_id()[1]
    return True

def extract_input(pdb_file, model, tokenizer):
    parser = PDBParser()
    structure = parser.get_structure("protein", pdb_file)
    model0 = structure[0]

    mapping_file = os.path.join('/content/map', 'pdb_id_mapping.csv')
    pdb_id_map = pd.read_csv(mapping_file, header=None, index_col=0).squeeze().to_dict()

    #extracting the file name as it contains the id
    filename = os.path.basename(pdb_file)
    pdb_id = filename[3:7]
    pdb_id = pdb_id
    #print(pdb_id)

    full_pdb_id = pdb_id_map.get(pdb_id) #pdb id with the correct chain


    chain_A = model0[full_pdb_id[-1]]  # and we get chain A

    # dictionary converting 3-letter codes to 1-letter codes

    #try:
    #    chain_A = model0['A']
    #except KeyError:
    #    print(f"Chain A not found in {pdb_file}")
    #    return None, None, None, None, None

    #if not is_chain_continuous(chain_A):
    #    print(f"Chain A in {pdb_file} is discontinuous")
    #    return None, None, None, None, None

    # this is a very common need in bioinformatics of proteins
    d3to1 = {'CYS': 'C', 'ASP': 'D', 'SER': 'S', 'GLN': 'Q', 'LYS': 'K',
    'ILE': 'I', 'PRO': 'P', 'THR': 'T', 'PHE': 'F', 'ASN': 'N',
    'GLY': 'G', 'HIS': 'H', 'LEU': 'L', 'ARG': 'R', 'TRP': 'W',
    'ALA': 'A', 'VAL':'V', 'GLU': 'E', 'TYR': 'Y', 'MET': 'M'}

    sequence = []
    for residue in chain_A:
        # for simplicity we can use X for heteroatoms (ions and water)
        sequence.append(d3to1.get(residue.get_resname(), 'X'))  #converts water and ions to X
    #print(''.join(sequence))
    seq_example =  ' '.join(sequence)
    #return seq_example

#def extract_coordinates(pdb_file):
    structure.atom_to_internal_coordinates() # turns xyz coordinates into angles and bond lengths

    chain:PDB.Chain.Chain = list(structure.get_chains())[0]#iterator of chains, turns it into list, [0] first chain

    ic_chain: PDB.internal_coords.IC_Chain = chain.internal_coord #this access the internal chain coords of the chain object

    d: Dict[Tuple[PDB.internal_coords.AtomKey,
              PDB.internal_coords.AtomKey,
              PDB.internal_coords.AtomKey,
              PDB.internal_coords.AtomKey],
        PDB.internal_coords.Dihedron] = ic_chain.dihedra

    cnt = 1
    phi_angles = {}
    phi_angles_list = []
    psi_angles = {}
    psi_angles_list = []

    for key in d:
      if key[0].akl[3] == 'N' and key[1].akl[3] == 'CA' and key[2].akl[3] == 'C' and key[3].akl[3] == 'N':
          phi_angles[key] = d[key].angle
          phi_angles_list.append(d[key].angle)
      elif key[0].akl[3] == 'CA' and key[1].akl[3] == 'C' and key[2].akl[3] == 'N' and key[3].akl[3] == 'CA':
          psi_angles[key] = d[key].angle
          psi_angles_list.append(d[key].angle)


    structure.internal_to_atom_coordinates(verbose = False)#before it was true, you can change this back if theres any
    io = PDBIO() #this is to write a pdb file again
    io.set_structure(structure)#set structure, the structure you wan tin the pdb file
    phi_angles_list.append(0)
    psi_angles_list.append(0)

    phi = np.asarray(phi_angles_list,dtype=np.float32)
    psi = np.asarray(psi_angles_list,dtype=np.float32)
    angles = np.vstack((psi,phi))
    angle_tensor = torch.tensor(angles, dtype=torch.float32)

    #the ones im commenting out must be uncommented for our custom transformer
    #tokenizer = BertTokenizer.from_pretrained("Rostlab/prot_bert", do_lower_case=False )

    seq = re.sub(r"[UZOB]", "X", seq_example)

    encoded_input = tokenizer(seq, return_tensors='pt')
    #output = bert_model(**encoded_input)
    #embedded_pb = output.last_hidden_state
    #N, D = embedded_pb.size()[1], embedded_pb.size()[2]
    #embeddings = embedded_pb

    #from here on im directly using libraries to implement transformers
    #model_name = "facebook/esm2_t33_650M_UR50D"
    #model = AutoModelForSequenceClassification.from_pretrained(model_name)
    #tokenizer = AutoTokenizer.from_pretrained(model_name)

    #inputs = tokenizer.encode(
    #    seq,
    #    add_special_tokens=True,
    #    max_length=1024,
    #    return_attention_mask=True,
    #    return_tensors='pt',
    #    truncation = True #not sure if this is required
    #)

    #Make predictions
    outputs = model(**encoded_input)

    embeddings = outputs.last_hidden_state

    #print('N:', N,D)
    return seq, angle_tensor, encoded_input, outputs, embeddings

# %%
#model_name = "facebook/esm2_t33_650M_UR50D" #here we can change to our mmodel and our tokenizer later
#tokenizer = AutoTokenizer.from_pretrained(model_name)
#model = AutoModelForSequenceClassification.from_pretrained(model_name)

tokenizer = BertTokenizer.from_pretrained("Rostlab/prot_bert", do_lower_case=False )
model = BertModel.from_pretrained("Rostlab/prot_bert")

# Initialize and train transformer model
feed_forward_dim1 = 512
feed_forward_dim2 = 256
feed_forward_dim3 = 128
num_epochs = 20
#model = TransformerModel(embed_dim=D, feed_forward_dim1=feed_forward_dim1, feed_forward_dim2= feed_forward_dim2)
#model.forward(embeddings)
#criterion = MeanAngleErrorLoss()
#num_epochs = 20
#criterion = nn.MSELoss()
#criterion = nn.L1Loss()

#criterion  = AngularLoss()
#trainer = TransformerTrainer4(model, criterion, num_epochs, embedded_pb, angles)
#trainer.train()

# %%
len(df)
# Out:
# 1723

# %% [markdown]
# Extracting input files

# %% [markdown]
# If i try to run this code for alll the files in one go, it crashes, so run this multiple times and it will continue from where it stopped.

# %%
import os
import torch

directory_path = '/content/target directory'
target_path = '/content/map'
embeddings_file = os.path.join(target_path, 'embeddings.pt')
angles_file = os.path.join(target_path, 'angles.pt')

# Load existing tensors if they exist
if os.path.exists(embeddings_file) and os.path.exists(angles_file):
    embeddings = torch.load(embeddings_file)
    angles = torch.load(angles_file)
    start_index = embeddings.size(0)
else:
    embeddings = torch.zeros(0, 130, 1024)
    angles = torch.zeros(0, 2, 128)
    start_index = 0

# Number of files to process in this run
num_files_to_process = 8

# Iterate over the files to process
sequences = []
i = start_index

for filename in os.listdir(directory_path):
    if i >= start_index + num_files_to_process:
        break

    file_path = os.path.join(directory_path, filename)

    if os.path.isfile(file_path):
        sequence, angle, inputs, outputs, embedding = extract_input(file_path, model, tokenizer)
        if sequence is None or embedding is None or angle is None:
            print(f"Skipping {file_path} due to missing data")
            continue
        sequences.append(sequence)

        # Append the new data to the existing tensors
        embedding_length = min(embedding.size(1), 130)
        if i >= embeddings.size(0):
            embeddings = torch.cat([embeddings, torch.zeros(1, 130, 1024)], dim=0)
        embeddings[i, :embedding_length] = embedding[0, :, :]

        angle_length = min(angle.size(1), 130)
        if i >= angles.size(0):
            angles = torch.cat([angles, torch.zeros(1, 2, 128)], dim=0)
        angles[i, :, :angle_length] = angle[:, :]

        i += 1
        print(i)

# Save the updated tensors back to the files
torch.save(embeddings, embeddings_file)
torch.save(angles, angles_file)
# Out:
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# 13

# %%
angles = torch.load('/content/map/angles.pt')
phi_angles = angles[:,0,:]
psi_angles = angles[:,1,:]

print(angles.size())
print(phi_angles.size())
# Out:
# torch.Size([13, 2, 128])
# torch.Size([13, 128])

# %%
embeddings = torch.load('/content/map/embeddings.pt')
print(embeddings.size())
# Out:
# torch.Size([13, 130, 1024])

# %% [markdown]
# Dividing data into test and validation sets

# %%
total_size = len(angles)
train_size = int(0.8*total_size) #80 percent of data
val_size = int(0.1*total_size)
test_size = total_size - train_size - val_size

dataset = TensorDataset(angles,embeddings)

train_set, val_set, test_set = random_split(dataset, [train_size, val_size, test_size])

# %% [markdown]
# Ignore from here on

# %%
class CoordRegressionModel(nn.Module):
  def __init__(self, input_dim, output_dim):
    super(CoordRegressionModel, self).__init__()
    self.fc1 = nn.Linear(input_dim, 512)
    self.fc2 = nn.Linear(512, 256)
    self.fc3 = nn.Linear(256, output_dim)

  def forward(self, x):
    x = torch.relu(self.fc1(x))
    x = torch.relu(self.fc2(x))
    x = self.fc3(x)
    return x

bert_model = BertModel.from_pretrained("Rostlab/prot_bert")
output = bert_model(**encoded_input)
embedded_pb = output.last_hidden_state
N, D = embedded_pb.size()[1], embedded_pb.size()[2]
embeddings = embedded_pb
# Initialize and train transformer model
feed_forward_dim1 = 512
feed_forward_dim2 = 256
feed_forward_dim3 = 128
num_epochs = 20
model = TransformerModel(embed_dim=D, feed_forward_dim1=feed_forward_dim1, feed_forward_dim2= feed_forward_dim2)
#model.forward(embeddings)
criterion = MeanAngleErrorLoss()
num_epochs = 20
#criterion = nn.MSELoss()
#criterion = nn.L1Loss()

#criterion  = AngularLoss()
#trainer = TransformerTrainer2(model, criterion, num_epochs, embedded_pb, angles)
#trainer.train()
#model
'''
model = transformer(input_dim=embeddings.shape[1], output_dim=coordinates.shape[1])
criterion = nn.CustomLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
'''
# Training loop
for epoch in range(100):
    model.train()
    optimizer.zero_grad()
    outputs = model(embeddings)
    loss = criterion(outputs, coordinates)
    loss.backward()
    optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item()}")

# Predicting coordinates
model.eval()
with torch.no_grad():
    predicted_coordinates = model(embeddings)
    print(predicted_coordinates)

# %%
class SelfAttention(nn.Module):
    def __init__(self, embed_dim: int):
        super(SelfAttention, self).__init__()
        self.embed_dim = embed_dim
        self.w_q = nn.Parameter(torch.randn(embed_dim, embed_dim))
        self.w_k = nn.Parameter(torch.randn(embed_dim, embed_dim))
        self.w_v = nn.Parameter(torch.randn(embed_dim, embed_dim))

    def forward(self, embeddings_prot_bert: torch.Tensor) -> torch.Tensor:
        Q = torch.matmul(embeddings_prot_bert, self.w_q)
        K = torch.matmul(embeddings_prot_bert, self.w_k)
        V = torch.matmul(embeddings_prot_bert, self.w_v)

        scores = torch.matmul(Q, K.transpose(-1, -2)) / np.sqrt(K.size(-1))
        attn = torch.softmax(scores, dim=-1)
        attention_output = torch.matmul(attn, V)

        return attention_output

class TransformerModel(nn.Module):
    def __init__(self, embed_dim: int, feed_forward_dim1: int, feed_forward_dim2: int, output_dim: int = 2, dropout_rate: float = 0.1):
        super(TransformerModel, self).__init__()
        self.self_attention = SelfAttention(embed_dim)
        self.layer_norm1 = nn.LayerNorm(embed_dim)
        self.layer_norm2 = nn.LayerNorm(output_dim)
        self.dropout = nn.Dropout(dropout_rate)
        self.feed_forward = nn.Sequential(
            nn.Linear(embed_dim, feed_forward_dim1),
            nn.GELU(),
            self.dropout,
            nn.Linear(feed_forward_dim1, feed_forward_dim2),
            nn.GELU(),
            self.dropout,
            nn.Linear(feed_forward_dim2, output_dim)
        )

    def forward(self, embeddings: torch.Tensor) -> torch.Tensor:
        attention_output = self.self_attention(embeddings)
        normalized_attention_output = self.layer_norm1(attention_output)
        ff_output = self.feed_forward(normalized_attention_output)
        output = self.layer_norm2(ff_output)
        return ff_output
class CustomLoss(nn.Module):
    def __init__(self, predicted_angles, angles_tensor):
        super(CustomLoss, self).__init__()
        self.predicted_angles= predicted_angles
        self.angles_tensor= angles_tensor
    def forward(self):
        print(self.predicted_angles)
        print(self.angles_tensor)
        d_list = []
        for i in range(len(self.angles_tensor)):
            x1, y1 = self.predicted_angles[0][i]
            x2, y2 = self.angles_tensor[i]
            ax_x = torch.min(torch.abs(x2 - x1), torch.abs(360 - torch.abs(x2 - x1)))
            ax_y = torch.min(torch.abs(y2 - y1), torch.abs(360 - torch.abs(y2 - y1)))
            d = torch.sqrt(ax_x**2 + ax_y**2)
            d_list.append(d)
        d_tensor = torch.stack(d_list)
        return d_tensor.mean()
class TransformerTrainer:
    def __init__(self, model: nn.Module, CustomLoss: nn.Module, num_epochs: int, sequence: torch.Tensor, angles: torch.Tensor):
        self.model = model
        self.CustomLoss = CustomLoss
        self.num_epochs = num_epochs
        self.sequence = sequence
        self.angles_tensor = angles
        self.optimizer = optim.SGD(model.parameters(), lr=0.001)
        self.scheduler = optim.lr_scheduler.StepLR(self.optimizer, step_size=10, gamma=0.1)

    def train(self):
        for epoch in range(self.num_epochs):
            self.optimizer.zero_grad()
            predictions = self.model.forward(self.sequence)[:, :len(self.angles_tensor)]
            print(self.angles_tensor)
            loss = CustomLoss()
            loss.forward(torch.tensor(predictions, requires_grad=True), self.angles_tensor)
            #loss = self.criterion(predictions.squeeze(), self.angles_tensor)
            loss.backward(retain_graph=True)
            self.optimizer.step()
            #self.scheduler.step()
            #loss_list.append(loss.item())
            print(loss)
            print(f"Epoch {epoch + 1}/{self.num_epochs}, Loss: {loss.item()}")
        return loss

# %%
#with  using mean angle error loss directly
class TransformerTrainer2:
    def __init__(self, model: nn.Module, criterion: nn.Module, num_epochs: int, sequence: torch.Tensor, angles: np.ndarray):
        self.model = model
        self.criterion = criterion
        self.num_epochs = num_epochs
        self.sequence = sequence
        self.angles_tensor = torch.from_numpy(angles.T)
        self.optimizer = optim.SGD(model.parameters(), lr=0.005)

    def train(self):
        loss_list = []
        for epoch in range(self.num_epochs):
            self.optimizer.zero_grad()
            predictions = self.model.forward(self.sequence)[:, :len(self.angles_tensor)]

            loss = self.criterion(predictions.squeeze(), self.angles_tensor)


            loss.backward(retain_graph=True)
            #for name, param in self.model.named_parameters():
            #    if param.grad is not None:
            #        print(f"Gradient for {name}: {param.grad.norm()}")

            self.optimizer.step()
            loss_list.append(loss.item())

            print(f"Epoch {epoch + 1}/{self.num_epochs}, Loss: {loss.item()}")

class MeanAngleErrorLoss(nn.Module):
    def __init__(self):
        super(MeanAngleErrorLoss, self).__init__()

    def forward(self, predictions, angles):

        angular_diff_phi = torch.abs(predictions[:, 0] - angles[:, 0])
        alt_diff_phi = 2 * torch.pi - angular_diff_phi
        error_phi = torch.min(angular_diff_phi, alt_diff_phi)
        #print(predictions)

        angular_diff_psi = torch.abs(predictions[:, 1] - angles[:, 1])
        alt_diff_psi = 2 * torch.pi - angular_diff_psi
        error_psi = torch.min(angular_diff_psi, alt_diff_psi)


        error_combined = torch.stack((error_phi, error_psi), dim=1)
        #print(np.shape(error_combined))
        mse = torch.mean(error_combined ** 2)
        #maybe we can use squeeze here
        return mse

# %%
#with  using mean angle error loss with mse loss
class TransformerTrainer3:
    def __init__(self, model: nn.Module, criterion: nn.Module, num_epochs: int, sequence: torch.Tensor, angles: np.ndarray):
        self.model = model
        self.criterion = criterion
        self.num_epochs = num_epochs
        self.sequence = sequence
        self.angles_tensor = torch.from_numpy(angles.T).float()
        self.optimizer = optim.SGD(model.parameters(), lr=0.005)
        self.empty_tensor = torch.zeros_like(self.angles_tensor)

    def train(self):
        loss_list = []
        for epoch in range(self.num_epochs):
            self.optimizer.zero_grad()
            predictions = self.model.forward(self.sequence)[:, :len(self.angles_tensor)]
            mean_angle_error = MeanAngleErrorLoss2()(predictions.squeeze(), self.angles_tensor)
            loss = self.criterion(mean_angle_error, self.empty_tensor)


            loss.backward(retain_graph=True)
            self.optimizer.step()
            loss_list.append(loss.item())

            print(f"Epoch {epoch + 1}/{self.num_epochs}, Loss: {loss.item()}")

class MeanAngleErrorLoss2(nn.Module):
    def __init__(self):
        super(MeanAngleErrorLoss2, self).__init__()


    def forward(self, predictions, angles):

        angular_diff_phi = torch.abs(predictions[:, 0] -angles[:, 0])
        alt_diff_phi = 2 * torch.pi - angular_diff_phi
        error_phi = torch.min(angular_diff_phi, alt_diff_phi)

        angular_diff_psi = torch.abs(predictions[:, 1] - angles[:, 1])
        alt_diff_psi = 2 * torch.pi - angular_diff_psi
        error_psi = torch.min(angular_diff_psi, alt_diff_psi)

        error_combined = torch.stack((error_phi, error_psi), dim=1)
        #print(np.shape(error_combined))
        #mse = torch.mean(error_combined ** 2)
        #maybe we can use squeeze here
        return error_combined

# %%
#checking whats wrong with  angle loss, by checking gradients and scaling to mse loss
class TransformerTrainer4:
    def __init__(self, model: nn.Module, criterion: nn.Module, num_epochs: int, sequence: torch.Tensor, angles: np.ndarray):
        self.model = model
        self.criterion = criterion
        self.num_epochs = num_epochs
        self.sequence = sequence
        self.angles_tensor = torch.from_numpy(angles.T)
        self.optimizer = optim.SGD(model.parameters(), lr=0.005)

    def train(self):
        loss_list = []
        for epoch in range(self.num_epochs):
            self.optimizer.zero_grad()
            predictions = self.model.forward(self.sequence)[:, :len(self.angles_tensor)]

            #loss = self.criterion(predictions.squeeze(), self.angles_tensor)


            #loss.backward(retain_graph=True)
            custom_loss = self.criterion(predictions.squeeze(), self.angles_tensor)
            scaled_custom_loss = 2 * custom_loss

            # Compute MSE loss for comparison
            mse_loss = nn.MSELoss()(predictions.squeeze(), self.angles_tensor)
            scaled_custom_loss = scaled_custom_loss + mse_loss

            print(f"Epoch {epoch + 1}/{self.num_epochs}, Scaled Custom Loss: {scaled_custom_loss.item()}, MSE Loss: {mse_loss.item()}")

            scaled_custom_loss.backward(retain_graph=True)


            #for name, param in self.model.named_parameters():
            #    if param.grad is not None:
            #        print(f"Gradient for {name}: {param.grad.norm()}")

            self.optimizer.step()
            loss_list.append(scaled_custom_loss.item())

            print(f"Epoch {epoch + 1}/{self.num_epochs}, Loss: {scaled_custom_loss.item()}")

# %%
class AngularLoss(nn.Module):
    def __init__(self):
        super(AngularLoss, self).__init__()

    def forward(self, predicted_angles, angles_tensor):
        predicted_angles_phi, predicted_angles_psi = predicted_angles[:, 0], predicted_angles[:, 1]
        angles_tensor_phi, angles_tensor_psi = angles_tensor[:, 0], angles_tensor[:, 1]

        predicted_angles_phi = (predicted_angles_phi + torch.pi) % (2 * torch.pi) - torch.pi
        angles_tensor_phi = (angles_tensor_phi + torch.pi) % (2 * torch.pi) - torch.pi
        predicted_angles_psi = (predicted_angles_psi + torch.pi) % (2 * torch.pi) - torch.pi
        angles_tensor_psi = (angles_tensor_psi + torch.pi) % (2 * torch.pi) - torch.pi

        difference_phi = torch.abs(predicted_angles_phi - angles_tensor_phi)
        loss_phi = torch.mean(torch.min(difference_phi, 2 * torch.pi - difference_phi))

        difference_psi = torch.abs(predicted_angles_psi - angles_tensor_psi)
        loss_psi = torch.mean(torch.min(difference_psi, 2 * torch.pi - difference_psi))

        loss = loss_phi+ loss_psi
        print(loss)
        return loss

class TransformerTrainer5:
    def __init__(self, model: nn.Module, criterion: nn.Module, num_epochs: int, sequence: torch.Tensor, angles: torch.Tensor):
        self.model = model
        self.criterion = criterion
        self.num_epochs = num_epochs
        self.sequence = sequence
        self.angles_tensor = angles
        self.optimizer = optim.AdamW(model.parameters(), lr=0.001)
        #self.scheduler = optim.lr_scheduler.StepLR(self.optimizer, step_size=10, gamma=0.1)

    def train(self):
        loss_list = []
        for epoch in range(self.num_epochs):
            self.optimizer.zero_grad()
            predictions = self.model.forward(self.sequence)[:, :len(self.angles_tensor)]
            #loss = CustomLoss()
            #loss.forward(torch.tensor(predictions, requires_grad=True), self.angles_tensor)
            loss = self.criterion(predictions.squeeze(), self.angles_tensor)
            loss.backward(retain_graph=True)
            self.optimizer.step()
            #self.scheduler.step()
            loss_list.append(loss.item())
            #print(f"Epoch {epoch + 1}/{self.num_epochs}, Loss: {loss.item()}")
        return loss

# %%
bert_model = BertModel.from_pretrained("Rostlab/prot_bert")
output = bert_model(**encoded_input)
embedded_pb = output.last_hidden_state
N, D = embedded_pb.size()[1], embedded_pb.size()[2]
embeddings = embedded_pb
# Initialize and train transformer model
feed_forward_dim1 = 512
feed_forward_dim2 = 256
feed_forward_dim3 = 128
num_epochs = 20
model = TransformerModel(embed_dim=D, feed_forward_dim1=feed_forward_dim1, feed_forward_dim2= feed_forward_dim2)
#model.forward(embeddings)
criterion = MeanAngleErrorLoss()
num_epochs = 20
#criterion = nn.MSELoss()
#criterion = nn.L1Loss()

#criterion  = AngularLoss()
trainer = TransformerTrainer4(model, criterion, num_epochs, embedded_pb, angles)
trainer.train()
model
